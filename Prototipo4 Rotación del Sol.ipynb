# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\Datos_pixeles.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]
# Out:
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
def generate_parabola(x,h,k, a):
    return a * (x - h)**2 + k

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1529

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0   17803.834
# 1                  1   18761.166
# 2                  2   18666.000
# 3                  3   18686.000
# 4                  4   18793.834

# %%
plt.plot(x_values[925:990], y_values[925:990])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()
dfb=df.iloc[925:990]
local_minima = []
for i in range(926, 988):
    if dfb[D][i] < dfb[D][i - 1] and dfb[D][i] < dfb[D][i + 1]:
        if dfb[D][i] <16000:
            local_minima.append(dfb.iloc[i-925])

# Convert the list of local minima to a DataFrame
df3 = pd.DataFrame(local_minima)
df3
# Out:
#      Distance_(pixels)  Gray_Value
# 945              945.0   14496.167
# 966              966.0   14590.000

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
plt.plot(x_values[234:240], y_values[234:240])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[234:240]
y=list(y_values)
y=y[234:240]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
print(centro)
PIXELES.append(centro)
# Out:
# 236.54871897574947

# %%
plt.plot(x_values[257:262], y_values[257:262])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[257:262]
y=list(y_values)
y=y[257:262]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
print(centro)
PIXELES.append(centro)
# Out:
# 258.8920298052482

# %%
plt.plot(x_values[278:285], y_values[278:285])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[278:285]
y=list(y_values)
y=y[278:285]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
print(centro)
PIXELES.append(centro)
# Out:
# 281.24198406325314

# %%
plt.plot(x_values[942:948], y_values[942:948])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[943:948]
y=list(y_values)
y=y[943:948]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[964:970], y_values[964:970])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[964:970]
y=list(y_values)
y=y[964:970]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[805:865], y_values[805:865])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.plot(x_values[833:838], y_values[833:838])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[833:838]
y=list(y_values)
y=y[833:838]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
print(centro)
PIXELES.append(centro)
# Out:
# 834.6956097857205

# %%
plt.plot(x_values[855:860], y_values[855:860])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[855:860]
y=list(y_values)
y=y[855:860]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[700:800], y_values[700:800])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.plot(x_values[731:736], y_values[731:736])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[731:736]
y=list(y_values)
y=y[731:736]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[753:758], y_values[753:758])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[753:758]
y=list(y_values)
y=y[753:758]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
print(centro)
PIXELES.append(centro)
# Out:
# 754.9268807062293

# %%
plt.plot(x_values[525:725], y_values[525:725])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.plot(x_values[549:555], y_values[549:555])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[549:555]
y=list(y_values)
y=y[549:555]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[572:577], y_values[572:577])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[572:577]
y=list(y_values)
y=y[572:577]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[636:641], y_values[636:641])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[636:641]
y=list(y_values)
y=y[636:641]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[659:664], y_values[659:664])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[659:664]
y=list(y_values)
y=y[659:664]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[400:510], y_values[400:510])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.plot(x_values[423:428], y_values[423:428])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[423:428]
y=list(y_values)
y=y[423:428]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[470:475], y_values[470:475])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[470:475]
y=list(y_values)
y=y[470:475]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[494:499], y_values[494:499])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[494:499]
y=list(y_values)
y=y[494:499]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[1080:1090], y_values[1080:1090])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[1080:1090]
y=list(y_values)
y=y[1080:1090]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[1185:1192], y_values[1185:1192])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[1185:1192]
y=list(y_values)
y=y[1185:1192]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
plt.plot(x_values[1208:1213], y_values[1208:1213])
plt.grid(True)
# Show the plot
plt.show()
X= list(df["Distance_(pixels)"])
X=X[1208:1213]
y=list(y_values)
y=y[1208:1213]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
PIXELES.append(centro)

# %%
PIXELES.sort()
PIXELES
# Out:
# [236.54871897574947,
#  258.8920298052482,
#  281.24198406325314,
#  424.94495456624537,
#  472.15129141503076,
#  495.857003550737,
#  551.6730520247094,
#  574.3949377157608,
#  638.2134164284831,
#  660.918468069753,
#  732.7243379333299,
#  754.9268807062293,
#  834.6956097857205,
#  856.6610174329554,
#  944.7060101960069,
#  966.4244186506374,
#  1084.4931969498987,
#  1187.9945741789038,
#  1209.7831455342214]

# %%
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Pix = [238, 260.5, 282.5, 426.6, 473.7, 497, 553, 576, 640, 662, 734, 756, 836, 858, 946, 968, 1085, 1190, 1211]
dif=[]
for i in range(len(PIXELES)):
    d=PIXELES[i]-Pix[i]
    dif.append(d)
Comparacion=  pd.DataFrame({
    'Posición Angstrom': moore,
    'Pixeles Estimados': Pix,
    'Pixeles Calculados': PIXELES,
    "Diferencia": dif
})

# %%
Comparacion
# Out:
#     Posición Angstrom  Pixeles Estimados  Pixeles Calculados  Diferencia
# 0            6281.178              238.0          236.548719   -1.451281
# 1            6281.956              260.5          258.892030   -1.607970
# 2            6282.726              282.5          281.241984   -1.258016
# 3            6287.749              426.6          424.944955   -1.655045
# 4            6289.398              473.7          472.151291   -1.548709
# 5            6290.221              497.0          495.857004   -1.142996
# 6            6292.162              553.0          551.673052   -1.326948
# 7            6292.958              576.0          574.394938   -1.605062
# 8            6295.178              640.0          638.213416   -1.786584
# 9            6295.960              662.0          660.918468   -1.081532
# 10           6298.457              734.0          732.724338   -1.275662
# 11           6299.228              756.0          754.926881   -1.073119
# 12           6302.000              836.0          834.695610   -1.304390
# 13           6302.764              858.0          856.661017   -1.338983
# 14           6305.810              946.0          944.706010   -1.293990
# 15           6306.565              968.0          966.424419   -1.575581
# 16           6310.636             1085.0         1084.493197   -0.506803
# 17           6314.235             1190.0         1187.994574   -2.005426
# 18           6314.977             1211.0         1209.783146   -1.216854

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [236.54871897574947, 258.8920298052482, 281.24198406325314, 424.94495456624537, 472.15129141503076, 495.857003550737, 551.6730520247094, 574.3949377157608, 638.2134164284831, 660.918468069753, 732.7243379333299, 754.9268807062293, 834.6956097857205, 856.6610174329554, 944.7060101960069, 966.4244186506374, 1084.4931969498987, 1187.9945741789038, 1209.7831455342214]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x+a))+(B*((x+b)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# 0.999999771100043
# C:\Users\juang\AppData\Local\Temp/ipykernel_5848/3032615193.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6301.141249459244

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1529):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %%
fig,ax = plt.subplots(ncols=2,figsize=(20,7))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][810:870], y_values[810:870])
    plt.grid(True)
# Show the plot

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][810:870], y_values[810:870])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[817:825], y_values[817:825])
X= list(df["Distance_(pixels)"])
X=X[817:825]
y=list(y_values)
y=y[817:825]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[847:853], y_values[847:853])
X= list(df["Distance_(pixels)"])
X=X[847:853]
y=list(y_values)
y=y[847:853]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][810:870], y_values[810:870])
    plt.grid(True)
# Show the plot

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][500:725], y_values[500:725])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[510:525], y_values[510:525])
X= list(df["Distance_(pixels)"])
X=X[510:525]
y=list(y_values)
y=y[510:525]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[710:718], y_values[710:718])
X= list(df["Distance_(pixels)"])
X=X[710:718]
y=list(y_values)
y=y[710:718]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1050:1125], y_values[1050:1125])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[1061:1065], y_values[1061:1065])
X= list(df["Distance_(pixels)"])
X=X[1061:1066]
y=list(y_values)
y=y[1061:1066]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[1107:1113], y_values[1107:1113])
X= list(df["Distance_(pixels)"])
X=X[1107:1113]
y=list(y_values)
y=y[1107:1113]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1180:1240], y_values[1180:1240])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[1198:1205], y_values[1198:1205])
X= list(df["Distance_(pixels)"])
X=X[1198:1205]
y=list(y_values)
y=y[1198:1205]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[1217:1225], y_values[1217:1225])
X= list(df["Distance_(pixels)"])
X=X[1217:1225]
y=list(y_values)
y=y[1217:1225]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[1231:1237], y_values[1231:1237])
X= list(df["Distance_(pixels)"])
X=X[1231:1237]
y=list(y_values)
y=y[1231:1237]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1280:1410], y_values[1280:1410])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[1295:1303], y_values[1295:1303])
X= list(df["Distance_(pixels)"])
X=X[1295:1303]
y=list(y_values)
y=y[1295:1303]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[1317:1321], y_values[1317:1321])
X= list(df["Distance_(pixels)"])
X=X[1317:1321]
y=list(y_values)
y=y[1317:1321]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[1331:1337], y_values[1331:1337])
X= list(df["Distance_(pixels)"])
X=X[1331:1337]
y=list(y_values)
y=y[1331:1337]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1400:1440], y_values[1400:1440])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[1416:1422], y_values[1416:1422])
X= list(df["Distance_(pixels)"])
X=X[1416:1422]
y=list(y_values)
y=y[1416:1422]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
plt.plot(x_values[1430:1438], y_values[1430:1438])
X= list(df["Distance_(pixels)"])
X=X[1430:1438]
y=list(y_values)
y=y[1430:1438]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][210:230], y_values[210:230])
    plt.grid(True)
# Show the plot

# %%
plt.plot(x_values[218:225], y_values[218:225])
X= list(df["Distance_(pixels)"])
X=X[218:225]
y=list(y_values)
y=y[218:225]
params, covariance = curve_fit(generate_parabola, X, y)
centro=params[0]
Centros.append(centro)

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.628881665409, 6290.970409532816, 6297.807542698571, 6301.510825749461, 6302.511091896733, 6309.894390595378, 6311.514414291956, 6314.673774778199, 6315.348947813029, 6315.8157063295075, 6318.0347288014855, 6318.728978207528, 6319.238765923965, 6322.173796493484, 6322.69131793753]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.628881665409, 6290.970409532816, 6297.807542698571, 6301.510825749461, 6302.511091896733, 6311.514414291956, 6315.348947813029, 6315.8157063295075, 6318.0347288014855, 6322.69131793753]

# %%
Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
#Hierros.pop(6)

# %% [markdown]
# Para el caso ignorando la linea de 6315.348947813029, se obtiene una velocidad promedio y una desviacion estandar de la siguiente forma:
#
#
# Aire: Promedio= 536. Desviacion Estandar= 236
#
#
# Ritz: Promedio= 561. Desviacion Estandar= 224

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 528.9606560059777
# 581.4670103228136
# --------------------
# 219.6647092236476
# 267.3191926386216
# --------------------
# 706.5537561830496
# 725.5949153828219
# --------------------
# 476.97273549996333
# 534.0625624797156
# --------------------
# 851.06885952614
# 851.06885952614
# --------------------
# 689.4201585489172
# 727.4197706974675
# --------------------
# 2024.5245580763224
# 2057.754325756767
# --------------------
# 223.3952363851753
# 237.63534087846386
# --------------------
# 836.4937361304659
# 812.7684702690024
# --------------------
# 294.8258131349536
# 313.7919812723943
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 685.1880218714612 .Desviación Estandar: 499.481172312297
# Promedio Ritz: 710.8882429224207 .Desviación Estandar: 497.09078025058085
# Promedio General: 698.0381323969409

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 683.7201278831807

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 653.9662649656167
# 701.4420054651972

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 131.21889166532253
# 83.77762790516171

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 369.703982021779

# %%
len(velocidades_Air)
# Out:
# 13

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 489.63509483804 .Desviación Estandar: 253.72945448802918
# Promedio Ritz: 384.97453846404596 .Desviación Estandar: 252.39151233377993
# Promedio General: 437.304816651043

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 640.060423325287
# 635.677388047411

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 637.8689056863491

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 462.11875455308103
# 472.8977241737832

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()
