# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# Out:
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\sol abril 12\F.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1530

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0    9187.714
# 1                  1    9344.286
# 2                  2    9477.429
# 3                  3    9514.429
# 4                  4    9517.143

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params))

# %%
plt.plot(x_values[160:220], y_values[160:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[164:172], y_values[164:172])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[164:172]
y=list(y_values)
y=y[164:172]
params, covariance = curve_fit(generate_parabola, X, y,p0=[168,1,8000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9985861956438054
# 167.43485485665778

# %%
plt.scatter(x_values[187:194], y_values[187:194])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[187:194]
y=list(y_values)
y=y[187:194]
params, covariance = curve_fit(generate_parabola, X, y,p0=[190,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9884142138745452
# 189.52213184606174

# %%
plt.scatter(x_values[209:217], y_values[209:217])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[209:217]
y=list(y_values)
y=y[209:217]
params, covariance = curve_fit(generate_parabola, X, y,p0=[212,1,7000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9974263212492162
# 212.05350586224347

# %%
plt.plot(x_values[870:905], y_values[870:905])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[872:878], y_values[872:878])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[872:878]
y=list(y_values)
y=y[872:878]
params, covariance = curve_fit(generate_parabola, X, y,p0=[875,1,9040,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9917611851512562
# 875.0387392200264

# %%
plt.scatter(x_values[894:903], y_values[894:903])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[894:903]
y=list(y_values)
y=y[894:903]
params, covariance = curve_fit(generate_parabola, X, y,p0=[897,1,9400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9967967509283171
# 896.3870991614967

# %%
plt.plot(x_values[740:795], y_values[740:795])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[762:770], y_values[762:770])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[762:770]
y=list(y_values)
y=y[762:770]
params, covariance = curve_fit(generate_parabola, X, y,p0=[765,1,9150,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986465337720082
# 765.0159495964813

# %%
plt.scatter(x_values[786:793], y_values[786:793])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[786:793]
y=list(y_values)
y=y[786:793]
params, covariance = curve_fit(generate_parabola, X, y,p0=[786.5,1,8600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982365165445781
# 786.234585239443

# %%
plt.plot(x_values[660:700], y_values[660:700])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[660:667], y_values[660:667])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[660:667]
y=list(y_values)
y=y[660:667]
params, covariance = curve_fit(generate_parabola, X, y,p0=[663.5,1,9500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9912988996054753
# 663.5470739545018

# %%
plt.scatter(x_values[683:690], y_values[683:690])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[683:690]
y=list(y_values)
y=y[683:690]
params, covariance = curve_fit(generate_parabola, X, y,p0=[686,1,5800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9985516114068345
# 685.3575734574302

# %%
plt.plot(x_values[475:600], y_values[475:600])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[479:486], y_values[479:486])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[479:486]
y=list(y_values)
y=y[479:486]
params, covariance = curve_fit(generate_parabola, X, y,p0=[482.5,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9989750217402379
# 482.6293227508899

# %%
plt.scatter(x_values[502:509], y_values[502:509])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[502:509]
y=list(y_values)
y=y[502:509]
params, covariance = curve_fit(generate_parabola, X, y,p0=[505,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9973389927058302
# 504.88442511107115

# %%
plt.scatter(x_values[565:572], y_values[565:572])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[565:572]
y=list(y_values)
y=y[565:572]
params, covariance = curve_fit(generate_parabola, X, y,p0=[569,1,9700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9981378048178512
# 568.7183042376201

# %%
plt.scatter(x_values[589:596], y_values[589:596])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[589:596]
y=list(y_values)
y=y[589:596]
params, covariance = curve_fit(generate_parabola, X, y,p0=[592,1,10000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.991245910540083
# 591.4469640952553

# %%
plt.plot(x_values[350:440], y_values[350:440])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[354:360], y_values[354:360])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[354:360]
y=list(y_values)
y=y[354:360]
params, covariance = curve_fit(generate_parabola, X, y,p0=[356,1,10100,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9988908489137468
# 355.56857787305097

# %%
plt.scatter(x_values[400:407], y_values[400:407])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[400:407]
y=list(y_values)
y=y[400:407]
params, covariance = curve_fit(generate_parabola, X, y,p0=[403,1,10800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986859168116089
# 402.8509443869229

# %%
plt.scatter(x_values[425:431], y_values[425:431])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[425:431]
y=list(y_values)
y=y[425:431]
params, covariance = curve_fit(generate_parabola, X, y,p0=[427,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9895747397116011
# 426.60162570562517

# %%
plt.plot(x_values[1000:1150], y_values[1000:1150])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[1011:1018], y_values[1011:1018])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1011:1018]
y=list(y_values)
y=y[1011:1018]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1015,1,9600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9906076814602822
# 1015.0830045844251

# %%
plt.scatter(x_values[1115:1121], y_values[1115:1121])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1115:1121]
y=list(y_values)
y=y[1115:1121]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1118,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9893088218985093
# 1118.3156701972077

# %%
plt.scatter(x_values[1138:1143], y_values[1138:1143])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1138:1143]
y=list(y_values)
y=y[1138:1143]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1140,1,9300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9782706662528995
# 1139.4620517627072

# %%
PIXELES.sort()
PIXELES
# Out:
# [167.43485485665778,
#  189.52213184606174,
#  212.05350586224347,
#  355.56857787305097,
#  402.8509443869229,
#  426.60162570562517,
#  482.6293227508899,
#  504.88442511107115,
#  568.7183042376201,
#  591.4469640952553,
#  663.5470739545018,
#  685.3575734574302,
#  765.0159495964813,
#  786.234585239443,
#  875.0387392200264,
#  896.3870991614967,
#  1015.0830045844251,
#  1118.3156701972077,
#  1139.4620517627072]

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [167.43485485665778, 189.52213184606174, 212.05350586224347, 355.56857787305097, 402.8509443869229, 426.60162570562517, 482.6293227508899, 504.88442511107115, 568.7183042376201, 591.4469640952553, 663.5470739545018, 685.3575734574302, 765.0159495964813, 786.234585239443, 875.0387392200264, 896.3870991614967, 1015.0830045844251, 1118.3156701972077, 1139.4620517627072]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x))+(B*((x)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# 0.9999985996845124
# C:\Users\juang\AppData\Local\Temp/ipykernel_12552/2300956569.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6303.557965734949

# %%
escala(x_values[:-1],*params_escala)
# Out:
# 0       6275.314619
# 1       6275.349657
# 2       6275.384695
# 3       6275.419733
# 4       6275.454770
#            ...
# 1524    6328.225000
# 1525    6328.259397
# 1526    6328.293794
# 1527    6328.328191
# 1528    6328.362587
# Name: Distance_(pixels), Length: 1529, dtype: float64

# %% [markdown]
# 6272 - 6325

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1530):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][740:800], y_values[740:800])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[747:757], y_values[747:757])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[747:757]
y=list(y_values)
y=y[747:757]
params, covariance = curve_fit(generate_parabola, X, y,p0=[751,1,5500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9996523258512642
# 751.1715567154147

# %%
plt.scatter(x_values[776:784], y_values[776:784])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[776:784]
y=list(y_values)
y=y[776:784]
params, covariance = curve_fit(generate_parabola, X, y,p0=[780,1,6750,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9991659728849119
# 780.2397831850103

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][440:660], y_values[440:660])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[443:454], y_values[443:454])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[443:454]
y=list(y_values)
y=y[443:454]
params, covariance = curve_fit(generate_parabola, X, y,p0=[448,1,8400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9970894308947599
# 448.5400898214874

# %%
plt.scatter(x_values[641:649], y_values[641:649])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[641:649]
y=list(y_values)
y=y[641:649]
params, covariance = curve_fit(generate_parabola, X, y,p0=[644,1,4400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9990420330569854
# 644.7252409808187

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][980:1050], y_values[980:1050])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[991:999], y_values[991:999])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[991:999]
y=list(y_values)
y=y[991:999]
params, covariance = curve_fit(generate_parabola, X, y,p0=[993,1,9000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9976840909887783
# 993.0053673290636

# %%
plt.scatter(x_values[1036:1043], y_values[1036:1043])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1036:1043]
y=list(y_values)
y=y[1036:1043]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1039,1,9600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998984950543088
# 1039.8150496864494

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1120:1170], y_values[1120:1170])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1126:1135], y_values[1126:1135])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1126:1135]
y=list(y_values)
y=y[1126:1135]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1131,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997048684362125
# 1131.3321863205738

# %%
plt.scatter(x_values[1147:1154], y_values[1147:1154])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1147:1154]
y=list(y_values)
y=y[1147:1154]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1150,1,5400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9989988587703258
# 1150.8039984549769

# %%
plt.scatter(x_values[1160:1168], y_values[1160:1168])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1160:1168]
y=list(y_values)
y=y[1160:1168]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1164,1,8500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9995044266957328
# 1164.5202876887656

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1210:1270], y_values[1210:1270])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1223:1235], y_values[1223:1235])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1223:1235]
y=list(y_values)
y=y[1223:1235]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1228,1,6500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998388163513748
# 1228.4370381360693

# %%
plt.scatter(x_values[1246:1252], y_values[1246:1252])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1246:1252]
y=list(y_values)
y=y[1246:1252]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1248,1,8600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9828768675455569
# 1248.675147332454

# %%
plt.scatter(x_values[1260:1268], y_values[1260:1268])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1260:1268]
y=list(y_values)
y=y[1260:1268]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1263,1,6600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9956489735933883
# 1263.7812901895131

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1340:1380], y_values[1340:1380])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1344:1352], y_values[1344:1352])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1344:1352]
y=list(y_values)
y=y[1344:1352]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1348,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987465701487126
# 1348.2018740950384

# %%
plt.scatter(x_values[1361:1369], y_values[1361:1369])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1361:1369]
y=list(y_values)
y=y[1361:1369]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1363,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987961250914861
# 1363.4912649793876

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][140:160], y_values[140:160])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[148:155], y_values[148:155])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[148:155]
y=list(y_values)
y=y[148:155]
params, covariance = curve_fit(generate_parabola, X, y,p0=[151,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9993755001779094
# 152.01842875811644

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.636293584912, 6290.988575785266, 6297.817531396931, 6301.516014179663, 6302.525162388382, 6309.900820690897, 6311.520952388219, 6314.685791870367, 6315.358710046712, 6315.832629743203, 6318.040011482605, 6318.738581537526, 6319.25989631992, 6322.171492814798, 6322.698490560951]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.636293584912, 6290.988575785266, 6297.817531396931, 6301.516014179663, 6302.525162388382, 6311.520952388219, 6315.358710046712, 6315.832629743203, 6318.040011482605, 6322.698490560951]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.358710046712

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 882.7534893141151
# 935.2599055949485
# --------------------
# 1085.3673132124056
# 1133.0219342378466
# --------------------
# 1182.0435946771108
# 1201.0847840772974
# --------------------
# 723.8111146077069
# 780.9009885931043
# --------------------
# 1520.3638738914206
# 1520.3638738914206
# --------------------
# 999.9758077913393
# 1037.9754593036785
# --------------------
# 1026.698531806996
# 1040.9386744570627
# --------------------
# 1087.1590845545193
# 1063.433798855714
# --------------------
# 634.9184117172995
# 653.8846013704483
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 1015.8990246192126 .Desviación Estandar: 245.07416743969574
# Promedio Ritz: 1040.7626689312801 .Desviación Estandar: 234.0673248889227
# Promedio General: 1028.3308467752463

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 989.2242168014806

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 1224.4852793099303
# 1271.9611101578596

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 1133.6712991800262
# 1086.2298767848263

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 260.46523445633187

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 1179.0782892449784 .Desviación Estandar: 45.40699006495208
# Promedio Ritz: 673.3475556205791 .Desviación Estandar: 412.88232116424723
# Promedio General: 926.2129224327787

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 1040.8726680720292
# 998.7933534817115

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 1019.8330107768703

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 221.95307559292064
# 307.72479647920636

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()

# %% [markdown]
# # Enfoque Espectografo

# %%
Hierros[0]
# Out:
# 6280.636293584912

# %%
Hierros[-1]
# Out:
# 6322.698490560951

# %%
enfoque=(Hierros[0]+Hierros[-1])/2
enfoque=enfoque/10000
sen_phi=(2*enfoque*1.2)/(2*np.cos((4.5*(np.pi/180))))
phy=np.arcsin(sen_phi)
phy=np.degrees(phy)
phy
# Out:
# 49.335516027487046

# %%
import csv

def export_to_csv(list1, list2, filename):
    if len(list1) != len(list2):
        raise ValueError("Lists must be of equal length")

    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Velocidades_Air', 'Velocidades_Ritz'])  # Writing header row
        for item1, item2 in zip(list1, list2):
            writer.writerow([item1, item2])

# %%
export_to_csv(velocidades_Air, velocidades_Ritz, 'Velocidades_F.csv')
