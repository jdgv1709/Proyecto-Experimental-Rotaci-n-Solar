# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# Out:
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\sol abril 12\E.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1530

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0    9972.429
# 1                  1   10078.429
# 2                  2   10263.143
# 3                  3   10313.571
# 4                  4   10292.143

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params))

# %%
plt.plot(x_values[160:220], y_values[160:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[164:172], y_values[164:172])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[164:172]
y=list(y_values)
y=y[164:172]
params, covariance = curve_fit(generate_parabola, X, y,p0=[168,1,8000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9978013420886359
# 167.46316025283824

# %%
plt.scatter(x_values[187:194], y_values[187:194])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[187:194]
y=list(y_values)
y=y[187:194]
params, covariance = curve_fit(generate_parabola, X, y,p0=[190,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9889217346308916
# 189.5590861897406

# %%
plt.scatter(x_values[209:217], y_values[209:217])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[209:217]
y=list(y_values)
y=y[209:217]
params, covariance = curve_fit(generate_parabola, X, y,p0=[212,1,7000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9945926857472646
# 212.21636180948684

# %%
plt.plot(x_values[870:905], y_values[870:905])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[873:878], y_values[873:878])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[873:878]
y=list(y_values)
y=y[873:878]
params, covariance = curve_fit(generate_parabola, X, y,p0=[875,1,9350,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9441294687504649
# 875.2844881710429

# %%
plt.scatter(x_values[894:903], y_values[894:903])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[894:903]
y=list(y_values)
y=y[894:903]
params, covariance = curve_fit(generate_parabola, X, y,p0=[897,1,9400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9959321978642055
# 896.8750211313275

# %%
plt.plot(x_values[740:795], y_values[740:795])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[761:770], y_values[761:770])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[761:770]
y=list(y_values)
y=y[761:770]
params, covariance = curve_fit(generate_parabola, X, y,p0=[765,1,9150,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9850720205854031
# 764.8749456975069

# %%
plt.scatter(x_values[786:793], y_values[786:793])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[786:793]
y=list(y_values)
y=y[786:793]
params, covariance = curve_fit(generate_parabola, X, y,p0=[786.5,1,8600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9971477138650479
# 785.7677083534077

# %%
plt.plot(x_values[660:700], y_values[660:700])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[660:668], y_values[660:668])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[660:668]
y=list(y_values)
y=y[660:668]
params, covariance = curve_fit(generate_parabola, X, y,p0=[663.5,1,9500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9847307988330621
# 663.7115560741491

# %%
plt.scatter(x_values[683:690], y_values[683:690])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[683:690]
y=list(y_values)
y=y[683:690]
params, covariance = curve_fit(generate_parabola, X, y,p0=[686,1,5800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999373830774547
# 685.4717577644707

# %%
plt.plot(x_values[475:600], y_values[475:600])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[479:486], y_values[479:486])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[479:486]
y=list(y_values)
y=y[479:486]
params, covariance = curve_fit(generate_parabola, X, y,p0=[482.5,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9977459836366876
# 482.4527742191654

# %%
plt.scatter(x_values[502:509], y_values[502:509])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[502:509]
y=list(y_values)
y=y[502:509]
params, covariance = curve_fit(generate_parabola, X, y,p0=[505,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9995588442693367
# 505.0189627141295

# %%
plt.scatter(x_values[565:572], y_values[565:572])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[565:572]
y=list(y_values)
y=y[565:572]
params, covariance = curve_fit(generate_parabola, X, y,p0=[569,1,9700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998486318564546
# 569.0796641602718

# %%
plt.scatter(x_values[589:596], y_values[589:596])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[589:596]
y=list(y_values)
y=y[589:596]
params, covariance = curve_fit(generate_parabola, X, y,p0=[592,1,10000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987223277880183
# 591.5599686920733

# %%
plt.plot(x_values[350:440], y_values[350:440])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[353:360], y_values[353:360])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[353:360]
y=list(y_values)
y=y[353:360]
params, covariance = curve_fit(generate_parabola, X, y,p0=[356,1,10100,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9919952969037666
# 355.6938480315485

# %%
plt.scatter(x_values[400:407], y_values[400:407])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[400:407]
y=list(y_values)
y=y[400:407]
params, covariance = curve_fit(generate_parabola, X, y,p0=[403,1,10800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9923800228232821
# 403.0807193066422

# %%
plt.scatter(x_values[425:431], y_values[425:431])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[425:431]
y=list(y_values)
y=y[425:431]
params, covariance = curve_fit(generate_parabola, X, y,p0=[427,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998814427212824
# 426.5645478585667

# %%
plt.plot(x_values[1000:1150], y_values[1000:1150])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[1011:1018], y_values[1011:1018])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1011:1018]
y=list(y_values)
y=y[1011:1018]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1015,1,9600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9956452839670843
# 1014.5264727955587

# %%
plt.scatter(x_values[1115:1121], y_values[1115:1121])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1115:1121]
y=list(y_values)
y=y[1115:1121]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1118,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9944399272173462
# 1118.4307486458608

# %%
plt.scatter(x_values[1138:1144], y_values[1138:1144])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1138:1144]
y=list(y_values)
y=y[1138:1144]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1140,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.969570238152811
# 1139.6557502417854

# %%
PIXELES.sort()
PIXELES
# Out:
# [167.46316025283824,
#  189.5590861897406,
#  212.21636180948684,
#  355.6938480315485,
#  403.0807193066422,
#  426.5645478585667,
#  482.4527742191654,
#  505.0189627141295,
#  569.0796641602718,
#  591.5599686920733,
#  663.7115560741491,
#  685.4717577644707,
#  764.8749456975069,
#  785.7677083534077,
#  875.2844881710429,
#  896.8750211313275,
#  1014.5264727955587,
#  1118.4307486458608,
#  1139.6557502417854]

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [167.46316025283824, 189.5590861897406, 212.21636180948684, 355.6938480315485, 403.0807193066422, 426.5645478585667, 482.4527742191654, 505.0189627141295, 569.0796641602718, 591.5599686920733, 663.7115560741491, 685.4717577644707, 764.8749456975069, 785.7677083534077, 875.2844881710429, 896.8750211313275, 1014.5264727955587, 1118.4307486458608, 1139.6557502417854]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x))+(B*((x)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# 0.999998219657233
# C:\Users\juang\AppData\Local\Temp/ipykernel_9844/2300956569.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6303.5564331052165

# %%
escala(x_values[:-1],*params_escala)
# Out:
# 0       6275.310699
# 1       6275.345741
# 2       6275.380782
# 3       6275.415823
# 4       6275.450863
#            ...
# 1524    6328.225522
# 1525    6328.259923
# 1526    6328.294322
# 1527    6328.328721
# 1528    6328.363120
# Name: Distance_(pixels), Length: 1529, dtype: float64

# %% [markdown]
# 6272 - 6325

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1530):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][740:800], y_values[740:800])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[746:756], y_values[746:756])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[746:756]
y=list(y_values)
y=y[746:756]
params, covariance = curve_fit(generate_parabola, X, y,p0=[751,1,6000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999047471944881
# 751.0796179429684

# %%
plt.scatter(x_values[776:784], y_values[776:784])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[776:784]
y=list(y_values)
y=y[776:784]
params, covariance = curve_fit(generate_parabola, X, y,p0=[780,1,6750,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9956131182524762
# 779.9688359400011

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][440:660], y_values[440:660])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[443:454], y_values[443:454])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[443:454]
y=list(y_values)
y=y[443:454]
params, covariance = curve_fit(generate_parabola, X, y,p0=[448,1,8400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998412204388073
# 448.41101272995854

# %%
plt.scatter(x_values[641:649], y_values[641:649])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[641:649]
y=list(y_values)
y=y[641:649]
params, covariance = curve_fit(generate_parabola, X, y,p0=[644,1,4400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997279452813012
# 644.5247216529723

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][980:1050], y_values[980:1050])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[991:999], y_values[991:999])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[991:999]
y=list(y_values)
y=y[991:999]
params, covariance = curve_fit(generate_parabola, X, y,p0=[993,1,9000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9914475794095736
# 993.1561298863443

# %%
plt.scatter(x_values[1036:1043], y_values[1036:1043])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1036:1043]
y=list(y_values)
y=y[1036:1043]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1039,1,9600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9962221503703426
# 1039.5654506002284

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1120:1170], y_values[1120:1170])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1126:1135], y_values[1126:1135])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1126:1135]
y=list(y_values)
y=y[1126:1135]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1131,1,7500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986489091764211
# 1131.2272562962187

# %%
plt.scatter(x_values[1147:1154], y_values[1147:1154])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1147:1154]
y=list(y_values)
y=y[1147:1154]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1150,1,5400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9972620133576581
# 1150.6095852892665

# %%
plt.scatter(x_values[1160:1168], y_values[1160:1168])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1160:1168]
y=list(y_values)
y=y[1160:1168]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1164,1,8500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982268355080449
# 1164.1614616872348

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1210:1270], y_values[1210:1270])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1223:1235], y_values[1223:1235])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1223:1235]
y=list(y_values)
y=y[1223:1235]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1228,1,6500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9985513464100748
# 1228.3074379300688

# %%
plt.scatter(x_values[1247:1252], y_values[1247:1252])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1247:1252]
y=list(y_values)
y=y[1247:1252]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1248,1,8600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986662678551869
# 1248.4154952423035

# %%
plt.scatter(x_values[1260:1268], y_values[1260:1268])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1260:1268]
y=list(y_values)
y=y[1260:1268]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1263,1,6600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9971813175206674
# 1263.4615509532493

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1340:1380], y_values[1340:1380])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1344:1352], y_values[1344:1352])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1344:1352]
y=list(y_values)
y=y[1344:1352]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1348,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9959947091325844
# 1348.443661342002

# %%
plt.scatter(x_values[1361:1369], y_values[1361:1369])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1361:1369]
y=list(y_values)
y=y[1361:1369]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1363,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997073398488029
# 1363.4470376021802

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][140:160], y_values[140:160])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[148:155], y_values[148:155])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[148:155]
y=list(y_values)
y=y[148:155]
params, covariance = curve_fit(generate_parabola, X, y,p0=[151,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987819462094756
# 151.78397442205818

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.624625829517, 6290.981486606744, 6297.8085444081, 6301.511117562333, 6302.51413761211, 6309.905039096895, 6311.511449022658, 6314.6815627520555, 6315.351445565905, 6315.819725127259, 6318.035214271145, 6318.729354640106, 6319.248640823036, 6322.179848805214, 6322.697030441872]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.624625829517, 6290.981486606744, 6297.8085444081, 6301.511117562333, 6302.51413761211, 6311.511449022658, 6315.351445565905, 6315.819725127259, 6318.035214271145, 6322.697030441872]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.351445565905

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 325.8170253167236
# 378.3233440545704
# --------------------
# 747.5364741865598
# 795.1910415110422
# --------------------
# 754.237917327052
# 773.2790795554514
# --------------------
# 490.855666086997
# 547.9454957104876
# --------------------
# 995.945255309384
# 995.945255309384
# --------------------
# 548.5716462043304
# 586.5712404999413
# --------------------
# 414.15541841139344
# 428.3955319657602
# --------------------
# 859.529467171442
# 835.8041994869595
# --------------------
# 565.6863242953225
# 584.6525095685544
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 633.5927993676894 .Desviación Estandar: 206.82186431180583
# Promedio Ritz: 658.45641085135 .Desviación Estandar: 191.90890830182826
# Promedio General: 646.0246051095197

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 1189.647410764578

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 1023.7052256174519
# 1071.1810246695152

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 599.6964520989812
# 552.255114203674

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 656.7001491743895

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 811.7008388582166 .Desviación Estandar: 212.00438675923533
# Promedio Ritz: 604.4776316890318 .Desviación Estandar: 52.22251748535774
# Promedio General: 708.0892352736241

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 709.6153568991846
# 683.8536654758108

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 696.7345111874978

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 254.64972663469968
# 205.21217109310686

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()

# %% [markdown]
# # Enfoque Espectografo

# %%
Hierros[0]
# Out:
# 6280.624625829517

# %%
Hierros[-1]
# Out:
# 6322.697030441872

# %%
enfoque=(Hierros[0]+Hierros[-1])/2
enfoque=enfoque/10000
sen_phi=(2*enfoque*1.2)/(2*np.cos((4.5*(np.pi/180))))
phy=np.arcsin(sen_phi)
phy=np.degrees(phy)
phy
# Out:
# 49.33544655563363

# %%
import csv

def export_to_csv(list1, list2, filename):
    if len(list1) != len(list2):
        raise ValueError("Lists must be of equal length")

    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Velocidades_Air', 'Velocidades_Ritz'])  # Writing header row
        for item1, item2 in zip(list1, list2):
            writer.writerow([item1, item2])

# %%
export_to_csv(velocidades_Air, velocidades_Ritz, 'Velocidades_E.csv')
