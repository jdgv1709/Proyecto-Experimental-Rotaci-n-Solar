# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\sol abril 12\A.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
x_values[1]
# Out:
# 1

# %%
plt.plot(x_values, y_values)
plt.title("Espectro de absorción del Sol en A")
plt.xlabel("Posición Pixeles")
plt.ylabel("Intensidad")
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1530

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0     6724.50
# 1                  1     6777.00
# 2                  2     6803.00
# 3                  3     6802.25
# 4                  4     6789.75

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params),label="R2= "+str(r2))

# %%
plt.plot(x_values[160:220], y_values[160:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[164:170], y_values[164:170])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[164:170]
y=list(y_values)
y=y[164:170]
params, covariance = curve_fit(generate_parabola, X, y,p0=[167,1,5900,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997441786891103
# 167.68559853327807

# %%
plt.scatter(x_values[185:195], y_values[185:195])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[185:195]
y=list(y_values)
y=y[185:195]
params, covariance = curve_fit(generate_parabola, X, y,p0=[190,1,6000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9934323322538907
# 190.01948752304705

# %%
plt.scatter(x_values[209:220], y_values[209:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[209:220]
y=list(y_values)
y=y[209:220]
params, covariance = curve_fit(generate_parabola, X, y,p0=[212,1,5300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9908823742162041
# 212.3460406227254

# %%
plt.plot(x_values[870:905], y_values[870:905])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[873:878], y_values[873:878])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[873:878]
y=list(y_values)
y=y[873:878]
params, covariance = curve_fit(generate_parabola, X, y,p0=[875,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9963967932787338
# 875.5845801173248

# %%
plt.scatter(x_values[894:901], y_values[894:901])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[894:901]
y=list(y_values)
y=y[894:901]
params, covariance = curve_fit(generate_parabola, X, y,p0=[896,1,6400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999114322104171
# 897.1043084005108

# %%
plt.plot(x_values[740:795], y_values[740:795])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[762:769], y_values[762:769])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[762:769]
y=list(y_values)
y=y[762:769]
params, covariance = curve_fit(generate_parabola, X, y,p0=[765,1,6500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
plt.title("Ajuste Gaussiano: Centro: "+str(centro))
plt.xlabel("Posición Pixeles")
plt.ylabel("Intensidad")
plt.legend()
# Out:
# 0.990405792573336
# 765.4499796950508

# %%
plt.scatter(x_values[785:790], y_values[785:790])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[785:790]
y=list(y_values)
y=y[785:790]
params, covariance = curve_fit(generate_parabola, X, y,p0=[787,1,6400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999985065283976
# 787.434823301695

# %%
plt.plot(x_values[660:700], y_values[660:700])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[662:668], y_values[662:668])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[662:668]
y=list(y_values)
y=y[662:668]
params, covariance = curve_fit(generate_parabola, X, y,p0=[663.5,1,5700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9947718608727552
# 663.600180299849

# %%
plt.scatter(x_values[683:690], y_values[683:690])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[683:690]
y=list(y_values)
y=y[683:690]
params, covariance = curve_fit(generate_parabola, X, y,p0=[686,1,5800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987008034790589
# 685.7794769336479

# %%
plt.plot(x_values[475:600], y_values[475:600])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[480:487], y_values[480:487])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[480:487]
y=list(y_values)
y=y[480:487]
params, covariance = curve_fit(generate_parabola, X, y,p0=[482.5,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9964057147546574
# 482.56188148291864

# %%
plt.scatter(x_values[502:508], y_values[502:508])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[502:508]
y=list(y_values)
y=y[502:508]
params, covariance = curve_fit(generate_parabola, X, y,p0=[505,1,6000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986802163096785
# 505.3696196057207

# %%
plt.scatter(x_values[566:572], y_values[566:572])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[566:572]
y=list(y_values)
y=y[566:572]
params, covariance = curve_fit(generate_parabola, X, y,p0=[569,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.995268631311799
# 569.1551729936339

# %%
plt.scatter(x_values[589:596], y_values[589:596])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[589:596]
y=list(y_values)
y=y[589:596]
params, covariance = curve_fit(generate_parabola, X, y,p0=[592,1,6000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9970073369827617
# 591.7098132195459

# %%
plt.plot(x_values[350:440], y_values[350:440])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[353:358], y_values[353:358])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[353:358]
y=list(y_values)
y=y[353:358]
params, covariance = curve_fit(generate_parabola, X, y,p0=[356,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9978446169971876
# 355.8856082207513

# %%
plt.scatter(x_values[400:405], y_values[400:405])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[400:405]
y=list(y_values)
y=y[400:405]
params, covariance = curve_fit(generate_parabola, X, y,p0=[403,1,6600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999722887109429
# 403.0735312645683

# %%
plt.scatter(x_values[425:430], y_values[425:430])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[425:430]
y=list(y_values)
y=y[425:430]
params, covariance = curve_fit(generate_parabola, X, y,p0=[427,1,6400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9870265447023021
# 426.8952728740133

# %%
plt.plot(x_values[1000:1150], y_values[1000:1150])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[1012:1018], y_values[1012:1018])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1012:1018]
y=list(y_values)
y=y[1012:1018]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1015,1,6900,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9835217073538937
# 1015.0470318791704

# %%
plt.scatter(x_values[1116:1121], y_values[1116:1121])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1116:1121]
y=list(y_values)
y=y[1116:1121]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1119,1,6800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9934021513246993
# 1118.874111241243

# %%
plt.scatter(x_values[1137:1143], y_values[1137:1143])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1137:1143]
y=list(y_values)
y=y[1137:1143]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1140,1,6600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9973583205548877
# 1140.0435273090766

# %%
PIXELES.sort()
PIXELES
# Out:
# [167.68559853327807,
#  190.01948752304705,
#  212.3460406227254,
#  355.8856082207513,
#  403.0735312645683,
#  426.8952728740133,
#  482.56188148291864,
#  505.3696196057207,
#  569.1551729936339,
#  591.7098132195459,
#  663.600180299849,
#  685.7794769336479,
#  765.4499796950508,
#  787.434823301695,
#  875.5845801173248,
#  897.1043084005108,
#  1015.0470318791704,
#  1118.874111241243,
#  1140.0435273090766]

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
len(PIXELES)
# Out:
# [167.68559853327807, 190.01948752304705, 212.3460406227254, 355.8856082207513, 403.0735312645683, 426.8952728740133, 482.56188148291864, 505.3696196057207, 569.1551729936339, 591.7098132195459, 663.600180299849, 685.7794769336479, 765.4499796950508, 787.434823301695, 875.5845801173248, 897.1043084005108, 1015.0470318791704, 1118.874111241243, 1140.0435273090766]
# 19

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x))+(B*((x)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore,label="Oxigeno Atmosferico")
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)

moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
plt.plot(x, y,"r", label="Ajuste Polinomico: R2: "+str(r2))
plt.grid(True)
plt.xlabel("Pixeles")
plt.ylabel("Angstrom")
plt.title("Escala Pixeles-Angstrom para el espectro A.")
print(r2)
print(params_escala)
plt.legend()
# Out:
# 0.999999776615609
# [ 3.50312848e-02  1.00000000e+00 -2.12096577e-07  1.00000000e+00
#   1.00000000e+00  1.00000000e+00  6.27530643e+03]
# C:\Users\juang\AppData\Local\Temp/ipykernel_5260/3532406751.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6303.542609416275

# %%
escala(x_values[:-1],*params_escala)
# Out:
# 0       6275.306425
# 1       6275.341456
# 2       6275.376487
# 3       6275.411517
# 4       6275.446547
#            ...
# 1524    6328.201493
# 1525    6328.235878
# 1526    6328.270262
# 1527    6328.304645
# 1528    6328.339029
# Name: Distance_(pixels), Length: 1529, dtype: float64

# %% [markdown]
# 6272 - 6325

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1530):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][740:800], y_values[740:800])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[743:758], y_values[743:758])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[743:758]
y=list(y_values)
y=y[743:758]
params, covariance = curve_fit(generate_parabola, X, y,p0=[750,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
plt.xlabel("Posición Pixeles")
plt.ylabel("Intensidad")
plt.title("Ajuste Gaussiano en linea de Fe; Centro: "+str(escala(centro,*params_escala))+" A")
plt.legend()
# Out:
# 0.9989395319046188
# 750.7766417114506

# %%
plt.scatter(x_values[776:784], y_values[776:784])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[776:784]
y=list(y_values)
y=y[776:784]
params, covariance = curve_fit(generate_parabola, X, y,p0=[780,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.998535684834684
# 779.5022362791248

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][440:660], y_values[440:660])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[443:454], y_values[443:454])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[443:454]
y=list(y_values)
y=y[443:454]
params, covariance = curve_fit(generate_parabola, X, y,p0=[448,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9974954476913751
# 447.9890091940957

# %%
plt.scatter(x_values[641:649], y_values[641:649])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[641:649]
y=list(y_values)
y=y[641:649]
params, covariance = curve_fit(generate_parabola, X, y,p0=[644,1,4400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9948068222562094
# 644.1292288565627

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][980:1050], y_values[980:1050])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[991:997], y_values[991:997])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[991:997]
y=list(y_values)
y=y[991:997]
params, covariance = curve_fit(generate_parabola, X, y,p0=[993,1,6300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999436696614169
# 993.0215823711184

# %%
plt.scatter(x_values[1036:1043], y_values[1036:1043])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1036:1043]
y=list(y_values)
y=y[1036:1043]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1039,1,6750,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.99603436143947
# 1039.1540573034968

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1120:1170], y_values[1120:1170])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1125:1135], y_values[1125:1135])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1125:1135]
y=list(y_values)
y=y[1125:1135]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1131,1,4800,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9985419442083462
# 1130.8310627905803

# %%
plt.scatter(x_values[1147:1153], y_values[1147:1153])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1147:1153]
y=list(y_values)
y=y[1147:1153]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1150,1,5400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9943209259656998
# 1150.1223505087712

# %%
plt.scatter(x_values[1160:1168], y_values[1160:1168])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1160:1168]
y=list(y_values)
y=y[1160:1168]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1164,1,5800,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9990705651767839
# 1163.9218859097157

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1210:1270], y_values[1210:1270])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1222:1235], y_values[1222:1235])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1222:1235]
y=list(y_values)
y=y[1222:1235]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1228,1,4500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9995000546088513
# 1228.1214599424748

# %%
plt.scatter(x_values[1245:1253], y_values[1245:1253])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1245:1253]
y=list(y_values)
y=y[1245:1253]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1248,1,6300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9915333488090822
# 1247.9394943670131

# %%
plt.scatter(x_values[1260:1268], y_values[1260:1268])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1260:1268]
y=list(y_values)
y=y[1260:1268]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1263,1,6600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9984073054326826
# 1263.0979740323132

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1340:1380], y_values[1340:1380])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1344:1351], y_values[1344:1351])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1344:1351]
y=list(y_values)
y=y[1344:1351]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1348,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9994038985044695
# 1348.468998778046

# %%
plt.scatter(x_values[1361:1369], y_values[1361:1369])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1361:1369]
y=list(y_values)
y=y[1361:1369]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1363,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982281782334984
# 1363.4613830827398

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][140:160], y_values[140:160])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[148:155], y_values[148:155])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[148:155]
y=list(y_values)
y=y[148:155]
params, covariance = curve_fit(generate_parabola, X, y,p0=[151,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9993629611478635
# 151.14048850970138

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.596268109907, 6290.957450574687, 6297.7830381082385, 6301.487479110555, 6302.484450686699, 6309.884055484081, 6311.480259399783, 6314.649648405063, 6315.31611903074, 6315.792765249401, 6318.009205777669, 6318.693055417232, 6319.216008164678, 6322.159407550784, 6322.675992300795]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.596268109907, 6290.957450574687, 6297.7830381082385, 6301.487479110555, 6302.484450686699, 6311.480259399783, 6315.31611903074, 6315.792765249401, 6318.009205777669, 6322.675992300795]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.31611903074

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# -1027.7807791931873
# -975.2746975272167
# --------------------
# -397.88719523820527
# -350.2328099881272
# --------------------
# -459.9329349293397
# -440.8918498181771
# --------------------
# -633.7382658805037
# -576.6486504144048
# --------------------
# -416.1810345438005
# -416.1810345438005
# --------------------
# -932.9167248540813
# -894.9173183412265
# --------------------
# -865.5484945698619
# -851.3084418012266
# --------------------
# -374.58403152453604
# -398.3092015428218
# --------------------
# -431.84493425767795
# -412.878812092528
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: -615.601599443466 .Desviación Estandar: 244.18567406040387
# Promedio Ritz: -590.7380906743923 .Desviación Estandar: 232.8372051452939
# Promedio General: -603.1698450589291

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 192.6825139203312

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# -491.4484850036354
# -443.97292589385756

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# -948.4376673193326
# -995.8787602271328

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# -312.6090891692996

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: -719.943076161484 .Desviación Estandar: 228.4945911578486
# Promedio Ritz: -654.2439246982162 .Desviación Estandar: 341.6348355289166
# Promedio General: -687.0935004298501

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# -565.6348361161525
# -589.0919659466517

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# -577.3634010314021

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 327.38823962264706
# 250.15339916678025

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()

# %% [markdown]
# # Enfoque Espectografo

# %%
Hierros[0]
# Out:
# 6280.596268109907

# %%
Hierros[-1]
# Out:
# 6322.675992300795

# %%
enfoque=(Hierros[0]+Hierros[-1])/2
enfoque=enfoque/10000
sen_phi=(2*enfoque*1.2)/(2*np.cos((4.5*(np.pi/180))))
phy=np.arcsin(sen_phi)
phy=np.degrees(phy)
phy
# Out:
# 49.33518515684699

# %%
import csv

def export_to_csv(list1, list2, filename):
    if len(list1) != len(list2):
        raise ValueError("Lists must be of equal length")

    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Velocidades_Air', 'Velocidades_Ritz'])  # Writing header row
        for item1, item2 in zip(list1, list2):
            writer.writerow([item1, item2])

# %%
export_to_csv(velocidades_Air, velocidades_Ritz, 'Velocidades_A.csv')
