# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# Out:
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\sol abril 12\H.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1530

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0    9875.750
# 1                  1    9983.125
# 2                  2   10088.750
# 3                  3   10134.875
# 4                  4   10137.625

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params))

# %%
plt.plot(x_values[160:220], y_values[160:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[165:172], y_values[165:172])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[165:172]
y=list(y_values)
y=y[165:172]
params, covariance = curve_fit(generate_parabola, X, y,p0=[168,1,9400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9874210720111458
# 167.44422363273202

# %%
plt.scatter(x_values[187:194], y_values[187:194])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[187:194]
y=list(y_values)
y=y[187:194]
params, covariance = curve_fit(generate_parabola, X, y,p0=[190,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9965252038231521
# 189.3953318042817

# %%
plt.scatter(x_values[209:217], y_values[209:217])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[209:217]
y=list(y_values)
y=y[209:217]
params, covariance = curve_fit(generate_parabola, X, y,p0=[212,1,8400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9854625767827135
# 211.95829226921717

# %%
plt.plot(x_values[870:905], y_values[870:905])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[872:878], y_values[872:878])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[872:878]
y=list(y_values)
y=y[872:878]
params, covariance = curve_fit(generate_parabola, X, y,p0=[875,1,9040,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9703824799195097
# 874.9182381923139

# %%
plt.scatter(x_values[894:901], y_values[894:901])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[894:901]
y=list(y_values)
y=y[894:901]
params, covariance = curve_fit(generate_parabola, X, y,p0=[897,1,9700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9913781985933754
# 896.7961480756908

# %%
plt.plot(x_values[740:795], y_values[740:795])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[762:770], y_values[762:770])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[762:770]
y=list(y_values)
y=y[762:770]
params, covariance = curve_fit(generate_parabola, X, y,p0=[765,1,9150,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9937518390629378
# 764.664639339233

# %%
plt.scatter(x_values[786:793], y_values[786:793])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[786:793]
y=list(y_values)
y=y[786:793]
params, covariance = curve_fit(generate_parabola, X, y,p0=[786.5,1,8600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9966679876246453
# 783.4088218647881

# %%
plt.plot(x_values[660:700], y_values[660:700])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[660:667], y_values[660:667])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[660:667]
y=list(y_values)
y=y[660:667]
params, covariance = curve_fit(generate_parabola, X, y,p0=[663.5,1,9400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9874056810603976
# 663.4204648360883

# %%
plt.scatter(x_values[683:690], y_values[683:690])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[683:690]
y=list(y_values)
y=y[683:690]
params, covariance = curve_fit(generate_parabola, X, y,p0=[686,1,5800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9936295362138848
# 685.2230814108522

# %%
plt.plot(x_values[475:600], y_values[475:600])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[479:486], y_values[479:486])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[479:486]
y=list(y_values)
y=y[479:486]
params, covariance = curve_fit(generate_parabola, X, y,p0=[482.5,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982117919948345
# 482.1648588517287

# %%
plt.scatter(x_values[502:509], y_values[502:509])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[502:509]
y=list(y_values)
y=y[502:509]
params, covariance = curve_fit(generate_parabola, X, y,p0=[505,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9963310440695571
# 504.7932413817448

# %%
plt.scatter(x_values[565:572], y_values[565:572])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[565:572]
y=list(y_values)
y=y[565:572]
params, covariance = curve_fit(generate_parabola, X, y,p0=[569,1,9700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9990151277028055
# 568.5158898030139

# %%
plt.scatter(x_values[589:596], y_values[589:596])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[589:596]
y=list(y_values)
y=y[589:596]
params, covariance = curve_fit(generate_parabola, X, y,p0=[592,1,10000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999325719629075
# 591.3390887748227

# %%
plt.plot(x_values[350:440], y_values[350:440])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[352:358], y_values[352:358])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[352:358]
y=list(y_values)
y=y[352:358]
params, covariance = curve_fit(generate_parabola, X, y,p0=[355,1,10000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987558402513865
# 355.3486383577942

# %%
plt.scatter(x_values[400:407], y_values[400:407])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[400:407]
y=list(y_values)
y=y[400:407]
params, covariance = curve_fit(generate_parabola, X, y,p0=[403,1,10800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9971207892640305
# 402.956764952465

# %%
plt.scatter(x_values[425:431], y_values[425:431])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[425:431]
y=list(y_values)
y=y[425:431]
params, covariance = curve_fit(generate_parabola, X, y,p0=[427,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9984122791495015
# 426.32653129938086

# %%
plt.plot(x_values[1000:1150], y_values[1000:1150])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[1011:1018], y_values[1011:1018])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1011:1018]
y=list(y_values)
y=y[1011:1018]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1015,1,9600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9987344535109312
# 1015.0333892057376

# %%
plt.scatter(x_values[1115:1121], y_values[1115:1121])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1115:1121]
y=list(y_values)
y=y[1115:1121]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1118,1,9900,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9798057377285924
# 1118.1816209396015

# %%
plt.scatter(x_values[1138:1143], y_values[1138:1143])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1138:1143]
y=list(y_values)
y=y[1138:1143]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1139,1,9620,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9973932763605707
# 1138.737748893724

# %%
PIXELES.sort()
PIXELES
# Out:
# [167.44422363273202,
#  189.3953318042817,
#  211.95829226921717,
#  355.3486383577942,
#  402.956764952465,
#  426.32653129938086,
#  482.1648588517287,
#  504.7932413817448,
#  568.5158898030139,
#  591.3390887748227,
#  663.4204648360883,
#  685.2230814108522,
#  764.664639339233,
#  783.4088218647881,
#  874.9182381923139,
#  896.7961480756908,
#  1015.0333892057376,
#  1118.1816209396015,
#  1138.737748893724]

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [167.44422363273202, 189.3953318042817, 211.95829226921717, 355.3486383577942, 402.956764952465, 426.32653129938086, 482.1648588517287, 504.7932413817448, 568.5158898030139, 591.3390887748227, 663.4204648360883, 685.2230814108522, 764.664639339233, 783.4088218647881, 874.9182381923139, 896.7961480756908, 1015.0333892057376, 1118.1816209396015, 1138.737748893724]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x))+(B*((x)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# 0.9999912202912384
# C:\Users\juang\AppData\Local\Temp/ipykernel_5060/2300956569.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6303.572553312513

# %%
escala(x_values[:-1],*params_escala)
# Out:
# 0       6275.305087
# 1       6275.340183
# 2       6275.375278
# 3       6275.410373
# 4       6275.445468
#            ...
# 1524    6328.223591
# 1525    6328.257942
# 1526    6328.292292
# 1527    6328.326641
# 1528    6328.360990
# Name: Distance_(pixels), Length: 1529, dtype: float64

# %% [markdown]
# 6272 - 6325

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1530):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][740:800], y_values[740:800])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[747:757], y_values[747:757])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[747:757]
y=list(y_values)
y=y[747:757]
params, covariance = curve_fit(generate_parabola, X, y,p0=[751,1,5500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999544418624006
# 751.6578676158007

# %%
plt.scatter(x_values[776:784], y_values[776:784])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[776:784]
y=list(y_values)
y=y[776:784]
params, covariance = curve_fit(generate_parabola, X, y,p0=[780,1,6750,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9993941040478191
# 780.571548766977

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][440:660], y_values[440:660])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[443:454], y_values[443:454])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[443:454]
y=list(y_values)
y=y[443:454]
params, covariance = curve_fit(generate_parabola, X, y,p0=[448,1,8400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9992074419666279
# 449.04727342648886

# %%
plt.scatter(x_values[641:649], y_values[641:649])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[641:649]
y=list(y_values)
y=y[641:649]
params, covariance = curve_fit(generate_parabola, X, y,p0=[644,1,4400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999833463573468
# 645.2638785034579

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][980:1050], y_values[980:1050])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[991:999], y_values[991:999])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[991:999]
y=list(y_values)
y=y[991:999]
params, covariance = curve_fit(generate_parabola, X, y,p0=[993,1,9000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9884450863051765
# 993.1628471739305

# %%
plt.scatter(x_values[1036:1043], y_values[1036:1043])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1036:1043]
y=list(y_values)
y=y[1036:1043]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1039,1,9600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997313363412739
# 1040.1525794567776

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1120:1170], y_values[1120:1170])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1126:1135], y_values[1126:1135])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1126:1135]
y=list(y_values)
y=y[1126:1135]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1131,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9996116622648133
# 1131.7233303964035

# %%
plt.scatter(x_values[1147:1154], y_values[1147:1154])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1147:1154]
y=list(y_values)
y=y[1147:1154]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1150,1,5400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9992102933758154
# 1151.18084025312

# %%
plt.scatter(x_values[1160:1168], y_values[1160:1168])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1160:1168]
y=list(y_values)
y=y[1160:1168]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1164,1,8500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9991488661936477
# 1164.7033826965958

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1210:1270], y_values[1210:1270])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1223:1235], y_values[1223:1235])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1223:1235]
y=list(y_values)
y=y[1223:1235]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1228,1,6500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998379060399597
# 1228.907727277496

# %%
plt.scatter(x_values[1246:1252], y_values[1246:1252])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1246:1252]
y=list(y_values)
y=y[1246:1252]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1249,1,8900,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9979119485546595
# 1248.9447958485466

# %%
plt.scatter(x_values[1260:1268], y_values[1260:1268])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1260:1268]
y=list(y_values)
y=y[1260:1268]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1263,1,6600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9972348976946633
# 1264.076309277995

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1340:1380], y_values[1340:1380])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1344:1352], y_values[1344:1352])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1344:1352]
y=list(y_values)
y=y[1344:1352]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1348,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9984990814400465
# 1349.4067302783071

# %%
plt.scatter(x_values[1361:1369], y_values[1361:1369])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1361:1369]
y=list(y_values)
y=y[1361:1369]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1364,1,7250,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9994182284288424
# 1364.278817081811

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][140:160], y_values[140:160])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[148:155], y_values[148:155])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[148:155]
y=list(y_values)
y=y[148:155]
params, covariance = curve_fit(generate_parabola, X, y,p0=[151,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9995742579642075
# 152.45180238207612

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.649890674675, 6291.015640216237, 6297.849580190727, 6301.547251965345, 6302.551175886287, 6309.920085901155, 6311.5458754424335, 6314.711011750394, 6315.383030634505, 6315.849959907961, 6318.065695487239, 6318.756775391884, 6319.278532164319, 6322.218752978824, 6322.730834238626]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.649890674675, 6291.015640216237, 6297.849580190727, 6301.547251965345, 6302.551175886287, 6311.5458754424335, 6315.383030634505, 6315.849959907961, 6318.065695487239, 6322.730834238626]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.383030634505

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 1531.7827872926905
# 1584.2893172458369
# --------------------
# 2375.107639766734
# 2422.7624658068853
# --------------------
# 2707.6553646220514
# 2726.6966509204326
# --------------------
# 2209.941617359212
# 2267.0317743497226
# --------------------
# 2757.755209424158
# 2757.755209424158
# --------------------
# 2183.805927785347
# 2221.8057293514344
# --------------------
# 1849.3090707273338
# 1863.54925245127
# --------------------
# 2305.875456899854
# 2282.150074753361
# --------------------
# 2168.505879331234
# 2187.472166005667
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 2232.1932170231794 .Desviación Estandar: 360.89408208362033
# Promedio Ritz: 2257.056960034308 .Desviación Estandar: 351.66223727116187
# Promedio General: 2244.6250885287436

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 1904.5450687582816

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 2421.8149572044435
# 2469.290977663511

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 2017.7790614550433
# 1970.3374991524843

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 2501.507424594824

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 2219.7970093297436 .Desviación Estandar: 202.0179478747001
# Promedio Ritz: 2235.9224618736544 .Desviación Estandar: 265.58496272116986
# Promedio General: 2227.859735601699

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 2202.8231700521987
# 2271.2207118099655

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 2237.021940931082

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 335.55088957770414
# 328.8359490741457

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()

# %% [markdown]
# # Enfoque Espectografo

# %%
Hierros[0]
# Out:
# 6280.649890674675

# %%
Hierros[-1]
# Out:
# 6322.730834238626

# %%
enfoque=(Hierros[0]+Hierros[-1])/2
enfoque=enfoque/10000
sen_phi=(2*enfoque*1.2)/(2*np.cos((4.5*(np.pi/180))))
phy=np.arcsin(sen_phi)
phy=np.degrees(phy)
phy
# Out:
# 49.335759143796686

# %%
import csv

def export_to_csv(list1, list2, filename):
    if len(list1) != len(list2):
        raise ValueError("Lists must be of equal length")

    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Velocidades_Air', 'Velocidades_Ritz'])  # Writing header row
        for item1, item2 in zip(list1, list2):
            writer.writerow([item1, item2])

# %%
export_to_csv(velocidades_Air, velocidades_Ritz, 'Velocidades_H.csv')
