# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# Out:
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\sol abril 12\D.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1530

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0    9548.429
# 1                  1    9663.143
# 2                  2    9826.143
# 3                  3    9886.571
# 4                  4    9889.714

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params))

# %%
plt.plot(x_values[160:220], y_values[160:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[164:172], y_values[164:172])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[164:172]
y=list(y_values)
y=y[164:172]
params, covariance = curve_fit(generate_parabola, X, y,p0=[168,1,8000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982028565056869
# 167.57754915663205

# %%
plt.scatter(x_values[186:193], y_values[186:193])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[186:193]
y=list(y_values)
y=y[186:193]
params, covariance = curve_fit(generate_parabola, X, y,p0=[190,1,7400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986932012093988
# 189.71953851680752

# %%
plt.scatter(x_values[209:217], y_values[209:217])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[209:217]
y=list(y_values)
y=y[209:217]
params, covariance = curve_fit(generate_parabola, X, y,p0=[212,1,7000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9961560814047767
# 212.03720091548183

# %%
plt.plot(x_values[870:905], y_values[870:905])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[873:878], y_values[873:878])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[873:878]
y=list(y_values)
y=y[873:878]
params, covariance = curve_fit(generate_parabola, X, y,p0=[875,1,9350,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9878899824127345
# 875.1412146143721

# %%
plt.scatter(x_values[894:903], y_values[894:903])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[894:903]
y=list(y_values)
y=y[894:903]
params, covariance = curve_fit(generate_parabola, X, y,p0=[897,1,7600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9955113642745611
# 896.4389692817281

# %%
plt.plot(x_values[740:795], y_values[740:795])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[762:769], y_values[762:769])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[762:769]
y=list(y_values)
y=y[762:769]
params, covariance = curve_fit(generate_parabola, X, y,p0=[765,1,6500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9802652276473973
# 765.0671086400498

# %%
plt.scatter(x_values[786:791], y_values[786:791])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[786:791]
y=list(y_values)
y=y[786:791]
params, covariance = curve_fit(generate_parabola, X, y,p0=[786.5,1,7700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9995641944829576
# 786.1224587000805

# %%
plt.plot(x_values[660:700], y_values[660:700])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[661:668], y_values[661:668])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[661:668]
y=list(y_values)
y=y[661:668]
params, covariance = curve_fit(generate_parabola, X, y,p0=[663.5,1,5700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9932169524326743
# 663.6581285490163

# %%
plt.scatter(x_values[683:690], y_values[683:690])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[683:690]
y=list(y_values)
y=y[683:690]
params, covariance = curve_fit(generate_parabola, X, y,p0=[686,1,5800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9970088231257176
# 685.4270566070807

# %%
plt.plot(x_values[475:600], y_values[475:600])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[479:486], y_values[479:486])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[479:486]
y=list(y_values)
y=y[479:486]
params, covariance = curve_fit(generate_parabola, X, y,p0=[482.5,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9945073087426369
# 482.5725413797298

# %%
plt.scatter(x_values[502:509], y_values[502:509])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[502:509]
y=list(y_values)
y=y[502:509]
params, covariance = curve_fit(generate_parabola, X, y,p0=[505,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9979763973330563
# 505.0003310093805

# %%
plt.scatter(x_values[565:572], y_values[565:572])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[565:572]
y=list(y_values)
y=y[565:572]
params, covariance = curve_fit(generate_parabola, X, y,p0=[569,1,9700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986310905465469
# 568.8356820899357

# %%
plt.scatter(x_values[589:596], y_values[589:596])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[589:596]
y=list(y_values)
y=y[589:596]
params, covariance = curve_fit(generate_parabola, X, y,p0=[592,1,10000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9966267564057887
# 591.5972114961652

# %%
plt.plot(x_values[350:440], y_values[350:440])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[353:360], y_values[353:360])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[353:360]
y=list(y_values)
y=y[353:360]
params, covariance = curve_fit(generate_parabola, X, y,p0=[356,1,1050,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9846180411641612
# 355.6180197414053

# %%
plt.scatter(x_values[400:406], y_values[400:406])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[400:406]
y=list(y_values)
y=y[400:406]
params, covariance = curve_fit(generate_parabola, X, y,p0=[403,1,10800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9945959356531435
# 402.86194965653465

# %%
plt.scatter(x_values[425:431], y_values[425:431])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[425:431]
y=list(y_values)
y=y[425:431]
params, covariance = curve_fit(generate_parabola, X, y,p0=[427,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9945770431445026
# 426.5173359339098

# %%
plt.plot(x_values[1000:1150], y_values[1000:1150])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[1012:1018], y_values[1012:1018])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1012:1018]
y=list(y_values)
y=y[1012:1018]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1015,1,6900,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9992317600740998
# 1015.051281910473

# %%
plt.scatter(x_values[1115:1121], y_values[1115:1121])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1115:1121]
y=list(y_values)
y=y[1115:1121]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1118,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9890567744040505
# 1118.4799098656963

# %%
plt.scatter(x_values[1138:1142], y_values[1138:1142])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1138:1142]
y=list(y_values)
y=y[1138:1142]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1140,1,7730,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 1.0
# 1139.7380702075839
# C:\Users\juang\AppData\Local\Temp/ipykernel_9852/3963844860.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, covariance = curve_fit(generate_parabola, X, y,p0=[1140,1,7730,1])

# %%
PIXELES.sort()
PIXELES
# Out:
# [167.57754915663205,
#  189.71953851680752,
#  212.03720091548183,
#  355.6180197414053,
#  402.86194965653465,
#  426.5173359339098,
#  482.5725413797298,
#  505.0003310093805,
#  568.8356820899357,
#  591.5972114961652,
#  663.6581285490163,
#  685.4270566070807,
#  765.0671086400498,
#  786.1224587000805,
#  875.1412146143721,
#  896.4389692817281,
#  1015.051281910473,
#  1118.4799098656963,
#  1139.7380702075839]

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [167.57754915663205, 189.71953851680752, 212.03720091548183, 355.6180197414053, 402.86194965653465, 426.5173359339098, 482.5725413797298, 505.0003310093805, 568.8356820899357, 591.5972114961652, 663.6581285490163, 685.4270566070807, 765.0671086400498, 786.1224587000805, 875.1412146143721, 896.4389692817281, 1015.051281910473, 1118.4799098656963, 1139.7380702075839]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x))+(B*((x)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# C:\Users\juang\AppData\Local\Temp/ipykernel_9852/2300956569.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)
# 0.9999986051842759

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6303.556208440921

# %%
escala(x_values[:-1],*params_escala)
# Out:
# 0       6275.307831
# 1       6275.342889
# 2       6275.377947
# 3       6275.413005
# 4       6275.448062
#            ...
# 1524    6328.209480
# 1525    6328.243846
# 1526    6328.278211
# 1527    6328.312576
# 1528    6328.346941
# Name: Distance_(pixels), Length: 1529, dtype: float64

# %% [markdown]
# 6272 - 6325

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1530):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][740:800], y_values[740:800])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[746:756], y_values[746:756])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[746:756]
y=list(y_values)
y=y[746:756]
params, covariance = curve_fit(generate_parabola, X, y,p0=[751,1,6000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997940997426664
# 751.1717689802219

# %%
plt.scatter(x_values[776:784], y_values[776:784])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[776:784]
y=list(y_values)
y=y[776:784]
params, covariance = curve_fit(generate_parabola, X, y,p0=[780,1,6750,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9983203642144068
# 780.2476097535388

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][440:660], y_values[440:660])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[443:454], y_values[443:454])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[443:454]
y=list(y_values)
y=y[443:454]
params, covariance = curve_fit(generate_parabola, X, y,p0=[448,1,8400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9979019981169887
# 448.47942990733674

# %%
plt.scatter(x_values[641:649], y_values[641:649])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[641:649]
y=list(y_values)
y=y[641:649]
params, covariance = curve_fit(generate_parabola, X, y,p0=[644,1,4400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998977340783372
# 644.7620729102359

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][980:1050], y_values[980:1050])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[990:999], y_values[990:999])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[990:999]
y=list(y_values)
y=y[990:999]
params, covariance = curve_fit(generate_parabola, X, y,p0=[993,1,9300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9915831316823721
# 993.0954603798593

# %%
plt.scatter(x_values[1036:1043], y_values[1036:1043])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1036:1043]
y=list(y_values)
y=y[1036:1043]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1039,1,9600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9993274145525165
# 1039.773980437411

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1120:1170], y_values[1120:1170])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1125:1135], y_values[1125:1135])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1125:1135]
y=list(y_values)
y=y[1125:1135]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1131,1,7500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9996481391723117
# 1131.349232009045

# %%
plt.scatter(x_values[1147:1154], y_values[1147:1154])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1147:1154]
y=list(y_values)
y=y[1147:1154]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1150,1,5400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998748401492443
# 1150.8235195965485

# %%
plt.scatter(x_values[1160:1168], y_values[1160:1168])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1160:1168]
y=list(y_values)
y=y[1160:1168]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1164,1,6700,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997066560765163
# 1164.5325614868432

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1210:1270], y_values[1210:1270])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1223:1235], y_values[1223:1235])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1223:1235]
y=list(y_values)
y=y[1223:1235]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1228,1,6500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998961560149724
# 1228.4456614211924

# %%
plt.scatter(x_values[1246:1251], y_values[1246:1251])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1246:1251]
y=list(y_values)
y=y[1246:1251]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1248,1,6850,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999165593164584
# 1248.6765787695558

# %%
plt.scatter(x_values[1260:1268], y_values[1260:1268])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1260:1268]
y=list(y_values)
y=y[1260:1268]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1263,1,6600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.988682011403523
# 1263.6133607809031

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1340:1380], y_values[1340:1380])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1344:1352], y_values[1344:1352])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1344:1352]
y=list(y_values)
y=y[1344:1352]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1348,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986760647409205
# 1348.4357483056494

# %%
plt.scatter(x_values[1361:1369], y_values[1361:1369])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1361:1369]
y=list(y_values)
y=y[1361:1369]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1363,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9991806013371841
# 1363.547398781464

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][140:160], y_values[140:160])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[148:155], y_values[148:155])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[148:155]
y=list(y_values)
y=y[148:155]
params, covariance = curve_fit(generate_parabola, X, y,p0=[151,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997917804073656
# 152.05133428379818

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.633274158368, 6290.985170778625, 6297.817810168886, 6301.5146379210455, 6302.523880205894, 6309.900278751943, 6311.51520559653, 6314.680539498548, 6315.353184565406, 6315.826593781565, 6318.032554140913, 6318.730437514528, 6319.245575700386, 6322.168999442688, 6322.689483060422]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.633274158368, 6290.985170778625, 6297.817810168886, 6301.5146379210455, 6302.523880205894, 6311.51520559653, 6315.353184565406, 6315.826593781565, 6318.032554140913, 6322.689483060422]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.353184565406

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 738.6273326034575
# 791.1337236417422
# --------------------
# 923.1036254069435
# 970.758220639252
# --------------------
# 1195.3139155000506
# 1214.3551057430923
# --------------------
# 658.3359259276996
# 715.4257874446004
# --------------------
# 1459.373940602478
# 1459.373940602478
# --------------------
# 727.0066509775495
# 765.0062678902917
# --------------------
# 740.1896771394406
# 754.4298061803826
# --------------------
# 733.3052154212369
# 709.5799577259837
# --------------------
# 207.8244348564527
# 226.79059748981513
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 820.3423020483676 .Desviación Estandar: 331.7190941477316
# Promedio Ritz: 845.2059341508486 .Desviación Estandar: 327.3645171981335
# Promedio General: 832.7741180996081

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 963.4758331589915

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 975.1256212898127
# 1022.601412648728

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 454.28320067887114
# 406.8418857947678

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 142.231364374621

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 714.7044109843418 .Desviación Estandar: 260.42121030547077
# Promedio Ritz: 274.5366250846944 .Desviación Estandar: 132.3052607100734
# Promedio General: 494.6205180345181

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 814.6637811302486
# 764.8773391813128

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 789.7705601557806

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 312.03571095588734
# 365.7049113789973

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()

# %% [markdown]
# # Enfoque Espectografo

# %%
Hierros[0]
# Out:
# 6280.633274158368

# %%
Hierros[-1]
# Out:
# 6322.689483060422

# %%
enfoque=(Hierros[0]+Hierros[-1])/2
enfoque=enfoque/10000
sen_phi=(2*enfoque*1.2)/(2*np.cos((4.5*(np.pi/180))))
phy=np.arcsin(sen_phi)
phy=np.degrees(phy)
phy
# Out:
# 49.335452381771525

# %%
import csv

def export_to_csv(list1, list2, filename):
    if len(list1) != len(list2):
        raise ValueError("Lists must be of equal length")

    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Velocidades_Air', 'Velocidades_Ritz'])  # Writing header row
        for item1, item2 in zip(list1, list2):
            writer.writerow([item1, item2])

# %%
export_to_csv(velocidades_Air, velocidades_Ritz, 'Velocidades_D.csv')
