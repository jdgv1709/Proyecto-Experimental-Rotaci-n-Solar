# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\Datos_pixeles.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %%
#def generate_parabola(x,h,k, a):
#    return a * (x - h)**2 + k

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1529

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0   17803.834
# 1                  1   18761.166
# 2                  2   18666.000
# 3                  3   18686.000
# 4                  4   18793.834

# %%
plt.plot(x_values[925:990], y_values[925:990])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()
dfb=df.iloc[925:990]
local_minima = []
for i in range(926, 988):
    if dfb[D][i] < dfb[D][i - 1] and dfb[D][i] < dfb[D][i + 1]:
        if dfb[D][i] <16000:
            local_minima.append(dfb.iloc[i-925])

# Convert the list of local minima to a DataFrame
df3 = pd.DataFrame(local_minima)
df3
# Out:
#      Distance_(pixels)  Gray_Value
# 945              945.0   14496.167
# 966              966.0   14590.000

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params))

# %%
plt.scatter(x_values[234:240], y_values[234:240])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[234:240]
y=list(y_values)
y=y[234:240]
params, covariance = curve_fit(generate_parabola, X, y,p0=[236,1,14000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999566761435114
# 236.5668872658364

# %%
plt.scatter(x_values[257:262], y_values[257:262])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[257:262]
y=list(y_values)
y=y[257:262]
params, covariance = curve_fit(generate_parabola, X, y,p0=[259,1,14000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9992830243623079
# 258.85813060230373

# %%
plt.scatter(x_values[278:285], y_values[278:285])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[278:285]
y=list(y_values)
y=y[278:285]
params, covariance = curve_fit(generate_parabola, X, y,p0=[281,1,14000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.972315805830799
# 281.235682050036

# %%
plt.scatter(x_values[942:948], y_values[942:948])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[943:948]
y=list(y_values)
y=y[943:948]
params, covariance = curve_fit(generate_parabola, X, y,p0=[944.5,1,14500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9980726573805764
# 944.5762631053192

# %%
plt.scatter(x_values[964:970], y_values[964:970])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[964:970]
y=list(y_values)
y=y[964:970]
params, covariance = curve_fit(generate_parabola, X, y,p0=[966.5,1,14500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998051969424089
# 966.3751213184992

# %%
plt.plot(x_values[805:865], y_values[805:865])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[833:838], y_values[833:838])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[833:838]
y=list(y_values)
y=y[833:838]
params, covariance = curve_fit(generate_parabola, X, y,p0=[834.5,1,14500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999996073334835
# 834.6031802858117

# %%
plt.scatter(x_values[855:860], y_values[855:860])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[855:860]
y=list(y_values)
y=y[855:860]
params, covariance = curve_fit(generate_parabola, X, y,p0=[856.5,1,14000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997270872002338
# 856.572138899628

# %%
plt.plot(x_values[700:800], y_values[700:800])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[731:736], y_values[731:736])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[731:736]
y=list(y_values)
y=y[731:736]
params, covariance = curve_fit(generate_parabola, X, y,p0=[732.5,1,13000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9991703294490365
# 732.6114787525421

# %%
plt.scatter(x_values[753:758], y_values[753:758])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[753:758]
y=list(y_values)
y=y[753:758]
params, covariance = curve_fit(generate_parabola, X, y,p0=[755,1,13000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9980895997832863
# 754.8775109305062

# %%
plt.plot(x_values[525:725], y_values[525:725])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[549:555], y_values[549:555])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[549:555]
y=list(y_values)
y=y[549:555]
params, covariance = curve_fit(generate_parabola, X, y,p0=[551.5,1,13500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9929613144128279
# 551.7046547524352

# %%
plt.scatter(x_values[572:577], y_values[572:577])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[572:577]
y=list(y_values)
y=y[572:577]
params, covariance = curve_fit(generate_parabola, X, y,p0=[574.5,1,12500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998770219176435
# 574.497411518842

# %%
plt.scatter(x_values[636:641], y_values[636:641])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[636:641]
y=list(y_values)
y=y[636:641]
params, covariance = curve_fit(generate_parabola, X, y,p0=[638,1,13500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999993396638158
# 638.297157146173

# %%
plt.scatter(x_values[659:664], y_values[659:664])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[659:664]
y=list(y_values)
y=y[659:664]
params, covariance = curve_fit(generate_parabola, X, y,p0=[661,1,13500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.998021773057796
# 660.864785652902

# %%
plt.plot(x_values[400:510], y_values[400:510])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[423:428], y_values[423:428])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[423:428]
y=list(y_values)
y=y[423:428]
params, covariance = curve_fit(generate_parabola, X, y,p0=[425,1,14400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9991285896160323
# 424.9322665147527

# %%
plt.scatter(x_values[470:475], y_values[470:475])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[470:475]
y=list(y_values)
y=y[470:475]
params, covariance = curve_fit(generate_parabola, X, y,p0=[472,1,14000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997722997926254
# 472.20277963222225

# %%
plt.scatter(x_values[494:499], y_values[494:499])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[494:499]
y=list(y_values)
y=y[494:499]
params, covariance = curve_fit(generate_parabola, X, y,p0=[496,1,13500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999918586742383
# 495.8048839117824

# %%
plt.scatter(x_values[1082:1087], y_values[1082:1087])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1082:1087]
y=list(y_values)
y=y[1082:1087]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1084,1,15500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9900544343113248
# 1084.191593340296

# %%
plt.scatter(x_values[1185:1192], y_values[1185:1192])
X= list(df["Distance_(pixels)"])
X=X[1185:1192]
y=list(y_values)
y=y[1185:1192]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1188,1,15600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9962536757886691
# 1188.056182150954

# %%
plt.scatter(x_values[1208:1213], y_values[1208:1213])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1208:1213]
y=list(y_values)
y=y[1208:1213]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1210,1,16400,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9942425662905775
# 1209.6522129239193

# %%
PIXELES.sort()
PIXELES
# Out:
# [236.5668872658364,
#  258.85813060230373,
#  281.235682050036,
#  424.9322665147527,
#  472.20277963222225,
#  495.8048839117824,
#  551.7046547524352,
#  574.497411518842,
#  638.297157146173,
#  660.864785652902,
#  732.6114787525421,
#  754.8775109305062,
#  834.6031802858117,
#  856.572138899628,
#  944.5762631053192,
#  966.3751213184992,
#  1084.191593340296,
#  1188.056182150954,
#  1209.6522129239193]

# %%
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Pix = [238, 260.5, 282.5, 426.6, 473.7, 497, 553, 576, 640, 662, 734, 756, 836, 858, 946, 968, 1085, 1190, 1211]
dif=[]
for i in range(len(PIXELES)):
    d=PIXELES[i]-Pix[i]
    dif.append(d)
Comparacion=  pd.DataFrame({
    'Posición Angstrom': moore,
    'Pixeles Estimados': Pix,
    'Pixeles Calculados': PIXELES,
    "Diferencia": dif
})

# %%
Comparacion
# Out:
#     Posición Angstrom  Pixeles Estimados  Pixeles Calculados  Diferencia
# 0            6281.178              238.0          236.566887   -1.433113
# 1            6281.956              260.5          258.858131   -1.641869
# 2            6282.726              282.5          281.235682   -1.264318
# 3            6287.749              426.6          424.932267   -1.667733
# 4            6289.398              473.7          472.202780   -1.497220
# 5            6290.221              497.0          495.804884   -1.195116
# 6            6292.162              553.0          551.704655   -1.295345
# 7            6292.958              576.0          574.497412   -1.502588
# 8            6295.178              640.0          638.297157   -1.702843
# 9            6295.960              662.0          660.864786   -1.135214
# 10           6298.457              734.0          732.611479   -1.388521
# 11           6299.228              756.0          754.877511   -1.122489
# 12           6302.000              836.0          834.603180   -1.396820
# 13           6302.764              858.0          856.572139   -1.427861
# 14           6305.810              946.0          944.576263   -1.423737
# 15           6306.565              968.0          966.375121   -1.624879
# 16           6310.636             1085.0         1084.191593   -0.808407
# 17           6314.235             1190.0         1188.056182   -1.943818
# 18           6314.977             1211.0         1209.652213   -1.347787

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [236.5668872658364, 258.85813060230373, 281.235682050036, 424.9322665147527, 472.20277963222225, 495.8048839117824, 551.7046547524352, 574.497411518842, 638.297157146173, 660.864785652902, 732.6114787525421, 754.8775109305062, 834.6031802858117, 856.572138899628, 944.5762631053192, 966.3751213184992, 1084.191593340296, 1188.056182150954, 1209.6522129239193]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x+a))+(B*((x+b)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# 0.9999998891310122
# C:\Users\juang\AppData\Local\Temp/ipykernel_4060/3032615193.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6301.143104794106

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(1529):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %%
fig,ax = plt.subplots(ncols=2,figsize=(20,7))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][810:870], y_values[810:870])
    plt.grid(True)
# Show the plot

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][810:870], y_values[810:870])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[817:825], y_values[817:825])
X= list(df["Distance_(pixels)"])
X=X[817:825]
y=list(y_values)
y=y[817:825]
params, covariance = curve_fit(generate_parabola, X, y,p0=[821,1,8000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999801332432541
# 820.7120438212803

# %%
plt.scatter(x_values[847:853], y_values[847:853])
X= list(df["Distance_(pixels)"])
X=X[847:853]
y=list(y_values)
y=y[847:853]
params, covariance = curve_fit(generate_parabola, X, y,p0=[849.5,1,10000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9985394572723207
# 849.4752737309984

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][810:870], y_values[810:870])
    plt.grid(True)
# Show the plot

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][500:725], y_values[500:725])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[510:525], y_values[510:525])
X= list(df["Distance_(pixels)"])
X=X[510:525]
y=list(y_values)
y=y[510:525]
params, covariance = curve_fit(generate_parabola, X, y,p0=[518,1,12000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9962147692935994
# 517.8485770703218

# %%
plt.scatter(x_values[710:718], y_values[710:718])
X= list(df["Distance_(pixels)"])
X=X[710:718]
y=list(y_values)
y=y[710:718]
params, covariance = curve_fit(generate_parabola, X, y,p0=[714,1,9500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9975874696029676
# 714.1109048205938

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1050:1125], y_values[1050:1125])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1061:1065], y_values[1061:1065])
X= list(df["Distance_(pixels)"])
X=X[1061:1066]
y=list(y_values)
y=y[1061:1066]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1063,1,15000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.995562174222554
# 1062.533885282747

# %%
plt.scatter(x_values[1107:1113], y_values[1107:1113])
X= list(df["Distance_(pixels)"])
X=X[1107:1113]
y=list(y_values)
y=y[1107:1113]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1109,1,15500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9990627783439503
# 1109.5180007441058

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1180:1240], y_values[1180:1240])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1198:1205], y_values[1198:1205])
X= list(df["Distance_(pixels)"])
X=X[1198:1205]
y=list(y_values)
y=y[1198:1205]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1201,1,11000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999668131874169
# 1200.9568137068618

# %%
plt.scatter(x_values[1217:1223], y_values[1217:1223])
X= list(df["Distance_(pixels)"])
X=X[1217:1223]
y=list(y_values)
y=y[1217:1223]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1220.5,1,12000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9908124808615869
# 1220.1550860290172

# %%
plt.scatter(x_values[1231:1237], y_values[1231:1237])
X= list(df["Distance_(pixels)"])
X=X[1231:1237]
y=list(y_values)
y=y[1231:1237]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1234,1,13500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999851104097881
# 1234.1482723375682

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1280:1410], y_values[1280:1410])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1295:1303], y_values[1295:1303])
X= list(df["Distance_(pixels)"])
X=X[1295:1303]
y=list(y_values)
y=y[1295:1303]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1298,1,8000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9991540441536729
# 1298.2979478158475

# %%
plt.scatter(x_values[1316:1321], y_values[1316:1321])
X= list(df["Distance_(pixels)"])
X=X[1316:1321]
y=list(y_values)
y=y[1316:1321]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1318.5,1,11700,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9940614429857524
# 1318.5101521673196

# %%
plt.scatter(x_values[1331:1337], y_values[1331:1337])
X= list(df["Distance_(pixels)"])
X=X[1331:1337]
y=list(y_values)
y=y[1331:1337]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1333,1,12100,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997845857679812
# 1333.2514364222914

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1400:1440], y_values[1400:1440])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1416:1422], y_values[1416:1422])
X= list(df["Distance_(pixels)"])
X=X[1416:1422]
y=list(y_values)
y=y[1416:1422]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1419,1,14100,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9960560174772134
# 1418.436135425302

# %%
plt.scatter(x_values[1430:1438], y_values[1430:1438])
X= list(df["Distance_(pixels)"])
X=X[1430:1438]
y=list(y_values)
y=y[1430:1438]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1433,1,9000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9983857516938667
# 1433.4753410706069

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][210:230], y_values[210:230])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[218:225], y_values[218:225])
X= list(df["Distance_(pixels)"])
X=X[218:225]
y=list(y_values)
y=y[218:225]
params, covariance = curve_fit(generate_parabola, X, y,p0=[221,1,11000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9997669112473848
# 220.94527190816152

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.627758112729, 6290.986636089991, 6297.813582333528, 6301.514812254696, 6302.512653503388, 6309.893025898962, 6311.517960854962, 6314.677658262963, 6315.34060875365, 6315.823719541275, 6318.037402275201, 6318.734524015808, 6319.242843326022, 6322.17843071877, 6322.69638268641]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.627758112729, 6290.986636089991, 6297.813582333528, 6301.514812254696, 6302.512653503388, 6311.517960854962, 6315.34060875365, 6315.823719541275, 6318.037402275201, 6322.69638268641]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.34060875365

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 475.33016449474803
# 527.8365094186305
# --------------------
# 992.9322193501195
# 1040.5868256822507
# --------------------
# 994.0571872266884
# 1013.0983646870459
# --------------------
# 666.6298094482485
# 723.7196725445607
# --------------------
# 925.3502403424174
# 925.3502403424174
# --------------------
# 857.8797732107606
# 895.8794067120336
# --------------------
# 603.758178246393
# 617.9983008068605
# --------------------
# 963.3511415397453
# 939.6258656389456
# --------------------
# 534.9727589431299
# 553.9389422732905
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 779.3623858669166 .Desviación Estandar: 196.8481028579932
# Promedio Ritz: 804.2260142340039 .Desviación Estandar: 188.88428065267323
# Promedio General: 791.7942000504602

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 618.8812255526383

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 838.3371484210799
# 885.8129181179431

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 324.65594402097764
# 277.21464964999274

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 589.4555338633575

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 581.4965462210288 .Desviación Estandar: 256.8406022000511
# Promedio Ritz: 433.33509175667507 .Desviación Estandar: 156.12044210668236
# Promedio General: 507.4158189888519

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 733.0113158997456
# 749.2097691447774

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 741.1105425222614

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 215.82239879011476
# 226.43942478052003

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()
