# %% [markdown]
# # Rotación Solar
# Juan David Galan Vargas - 202111470

# %% [markdown]
# # Prueba 1: Velocidad Radial del Sol

# %% [markdown]
# ## Importar Datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# Out:
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\juang\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Proyecto Experimental\sol abril 12\G.csv")
# Extract column names and data
x_column, y_column = df.columns
x_values = df[x_column]
y_values = df[y_column]

# %% [markdown]
# # Ajuste de Curva: Gaussiana

# %%
def generate_parabola(x, x0, a, y0, sigma):
    return y0 + a * -np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
fig,ax = plt.subplots(ncols=1,figsize=(45,15),sharey=True)

plt.plot(x_values, y_values)
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)

# Show the plot
plt.show()

# %%
len(x_values)
# Out:
# 1528

# %% [markdown]
# Confirmar Escala

# %%
D="Gray_Value"
df.head()
# Out:
#    Distance_(pixels)  Gray_Value
# 0                  0    8711.571
# 1                  1    8753.714
# 2                  2    8751.714
# 3                  3    8711.571
# 4                  4    8673.857

# %%
PIXELES=[]

# %% [markdown]
# # Ajuste Pixeles

# %%
def RESIDUALES(X,y,params):
    residuals =  y - generate_parabola(X,*params)
    ss_residual = np.sum(residuals**2)
    ss_total = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_residual / ss_total)
    print(r2)
    centro=params[0]
    print(centro)
    horizontal=np.linspace(X[0],X[-1],100)
    plt.plot(horizontal,generate_parabola(horizontal,*params))

# %%
plt.plot(x_values[160:220], y_values[160:220])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[164:172], y_values[164:172])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[164:172]
y=list(y_values)
y=y[164:172]
params, covariance = curve_fit(generate_parabola, X, y,p0=[168,1,8000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9966781550580757
# 165.4033301071399

# %%
plt.scatter(x_values[185:194], y_values[185:194])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[185:194]
y=list(y_values)
y=y[185:194]
params, covariance = curve_fit(generate_parabola, X, y,p0=[188,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9964957164170674
# 187.53682921128072

# %%
plt.scatter(x_values[207:214], y_values[207:214])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[207:214]
y=list(y_values)
y=y[207:214]
params, covariance = curve_fit(generate_parabola, X, y,p0=[210,1,7000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.982807692207969
# 210.00526475064137

# %%
plt.plot(x_values[870:905], y_values[870:905])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[870:876], y_values[870:876])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[870:876]
y=list(y_values)
y=y[870:876]
params, covariance = curve_fit(generate_parabola, X, y,p0=[873,1,8150,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9843770219017886
# 872.8523739904099

# %%
plt.scatter(x_values[891:901], y_values[891:901])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[891:901]
y=list(y_values)
y=y[891:901]
params, covariance = curve_fit(generate_parabola, X, y,p0=[895,1,8500,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9875972617622203
# 894.4973347431643

# %%
plt.plot(x_values[740:795], y_values[740:795])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[760:768], y_values[760:768])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[760:768]
y=list(y_values)
y=y[760:768]
params, covariance = curve_fit(generate_parabola, X, y,p0=[763,1,9150,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9965958633882139
# 763.0286239447925

# %%
plt.scatter(x_values[783:790], y_values[783:790])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[783:790]
y=list(y_values)
y=y[783:790]
params, covariance = curve_fit(generate_parabola, X, y,p0=[786.5,1,8600,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9970946683435522
# 782.1873196583329

# %%
plt.plot(x_values[660:700], y_values[660:700])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[659:666], y_values[659:666])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[659:666]
y=list(y_values)
y=y[659:666]
params, covariance = curve_fit(generate_parabola, X, y,p0=[661,1,7900,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9948241678732478
# 661.4387176636548

# %%
plt.scatter(x_values[680:688], y_values[680:688])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[680:688]
y=list(y_values)
y=y[680:688]
params, covariance = curve_fit(generate_parabola, X, y,p0=[683,1,7700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9937954330247616
# 683.3565713714827

# %%
plt.plot(x_values[475:600], y_values[475:600])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[478:485], y_values[478:485])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[478:485]
y=list(y_values)
y=y[478:485]
params, covariance = curve_fit(generate_parabola, X, y,p0=[480,1,6300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9856378115068263
# 480.47159520254877

# %%
plt.scatter(x_values[500:509], y_values[500:509])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[500:509]
y=list(y_values)
y=y[500:509]
params, covariance = curve_fit(generate_parabola, X, y,p0=[502,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9941405750667888
# 502.8330218219133

# %%
plt.scatter(x_values[563:570], y_values[563:570])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[563:570]
y=list(y_values)
y=y[563:570]
params, covariance = curve_fit(generate_parabola, X, y,p0=[567,1,9700,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9971298588666839
# 566.7424905487201

# %%
plt.scatter(x_values[587:596], y_values[587:596])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[587:596]
y=list(y_values)
y=y[587:596]
params, covariance = curve_fit(generate_parabola, X, y,p0=[590,1,10000,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9994813393559265
# 589.4998497287402

# %%
plt.plot(x_values[350:440], y_values[350:440])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[351:359], y_values[351:359])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[351:359]
y=list(y_values)
y=y[351:359]
params, covariance = curve_fit(generate_parabola, X, y,p0=[354,1,10100,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9965722992092945
# 353.21599738143067

# %%
plt.scatter(x_values[398:405], y_values[398:405])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[398:405]
y=list(y_values)
y=y[398:405]
params, covariance = curve_fit(generate_parabola, X, y,p0=[401,1,8800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9955502653634549
# 401.1460980284833

# %%
plt.scatter(x_values[422:430], y_values[422:430])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[422:430]
y=list(y_values)
y=y[422:430]
params, covariance = curve_fit(generate_parabola, X, y,p0=[425,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9923514636956359
# 424.54042920311366

# %%
plt.plot(x_values[1000:1150], y_values[1000:1150])
plt.title(f"Scatter Plot of {y_column} vs {x_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.scatter(x_values[1009:1017], y_values[1009:1017])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1009:1017]
y=list(y_values)
y=y[1009:1017]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1013,1,8250,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9839189881553699
# 1012.9198149846158

# %%
plt.scatter(x_values[1113:1119], y_values[1113:1119])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1113:1119]
y=list(y_values)
y=y[1113:1119]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1116,1,9800,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982680798244331
# 1116.0416140735817

# %%
plt.scatter(x_values[1137:1141], y_values[1137:1141])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1137:1141]
y=list(y_values)
y=y[1137:1141]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1138,1,9300,1])
centro=params[0]
PIXELES.append(centro)
RESIDUALES(X,y,params)
# Out:
# 1.0
# 1136.6950210553834
# C:\Users\juang\AppData\Local\Temp/ipykernel_16888/315077998.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, covariance = curve_fit(generate_parabola, X, y,p0=[1138,1,9300,1])

# %%
PIXELES.sort()
PIXELES
# Out:
# [165.4033301071399,
#  187.53682921128072,
#  210.00526475064137,
#  353.21599738143067,
#  401.1460980284833,
#  424.54042920311366,
#  480.47159520254877,
#  502.8330218219133,
#  566.7424905487201,
#  589.4998497287402,
#  661.4387176636548,
#  683.3565713714827,
#  763.0286239447925,
#  782.1873196583329,
#  872.8523739904099,
#  894.4973347431643,
#  1012.9198149846158,
#  1116.0416140735817,
#  1136.6950210553834]

# %% [markdown]
# # Escala Pixeles -Angstrom

# %%
print(PIXELES)
# Out:
# [165.4033301071399, 187.53682921128072, 210.00526475064137, 353.21599738143067, 401.1460980284833, 424.54042920311366, 480.47159520254877, 502.8330218219133, 566.7424905487201, 589.4998497287402, 661.4387176636548, 683.3565713714827, 763.0286239447925, 782.1873196583329, 872.8523739904099, 894.4973347431643, 1012.9198149846158, 1116.0416140735817, 1136.6950210553834]

# %%
def escala(x, A,a,B,b,C,c,D):
    return (A*(x))+(B*((x)**2))+D#+(C*((x+c)**3))
x=PIXELES
moore=[6281.178,6281.956,6282.726,6287.749,6289.398,6290.221,6292.162,6292.958,6295.178,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636,6314.235,6314.977]
Rowland1=[6287.285,6289.140,6290.221,6292.162,6292.958,6294.650,6295.96,6298.457,6299.228,6302,6302.764,6305.314,6306.565,6310.636]
Rowland2=[6287.945,6289.95,6290.221,6292.614,6292.958,6295.650,6295.96,6298.457,6299.228,6302,6302.764,6305.81,6306.565,6310.636]
params_escala, covariance = curve_fit(escala, x,moore)
plt.scatter(x, moore)
y=[]
for i in range(len(x)):
    Y=escala(x[i],*params_escala)
    y.append(Y)
plt.plot(x, y,"r")
moore=np.array(moore)
y= np.array(y)
residuals =  moore - y
ss_residual = np.sum(residuals**2)
ss_total = np.sum((moore - np.mean(moore))**2)
r2 = 1 - (ss_residual / ss_total)
print(r2)
# Out:
# 0.9999940007466996
# C:\Users\juang\AppData\Local\Temp/ipykernel_16888/2300956569.py:7: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_escala, covariance = curve_fit(escala, x,moore)

# %%
#APLICACION ESCALA
print(escala(810,*params_escala))
# Out:
# 6303.637273522798

# %%
escala(x_values[:-1],*params_escala)
# Out:
# 0       6275.382168
# 1       6275.417216
# 2       6275.452264
# 3       6275.487312
# 4       6275.522359
#            ...
# 1522    6328.252155
# 1523    6328.286581
# 1524    6328.321006
# 1525    6328.355431
# 1526    6328.389855
# Name: Distance_(pixels), Length: 1527, dtype: float64

# %% [markdown]
# 6272 - 6325

# %%
#APLICACION ESCALA
armstrong=[]
for i in range(len(x_values)):
    armstrong.append(escala(i,*params_escala))

plt.plot(armstrong[810:870], y_values[810:870])

plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(x_values[810:870], y_values[810:870])

# %% [markdown]
# # Prueba Ajuste

# %%
df["Armstrong"] = armstrong

# %%
posiciones=[armstrong,x_values]

# %%
Centros=[]

# %% [markdown]
# # Ajuste Curvas Angstrom

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][740:800], y_values[740:800])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[747:757], y_values[747:757])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[747:757]
y=list(y_values)
y=y[747:757]
params, covariance = curve_fit(generate_parabola, X, y,p0=[750,1,5500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998843302725214
# 749.594518429683

# %%
plt.scatter(x_values[776:784], y_values[776:784])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[776:784]
y=list(y_values)
y=y[776:784]
params, covariance = curve_fit(generate_parabola, X, y,p0=[778,1,6750,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9975582341655862
# 778.5677163307003

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][440:660], y_values[440:660])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[443:454], y_values[443:454])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[443:454]
y=list(y_values)
y=y[443:454]
params, covariance = curve_fit(generate_parabola, X, y,p0=[446,1,8400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9983287437402061
# 446.8927236775299

# %%
plt.scatter(x_values[641:649], y_values[641:649])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[641:649]
y=list(y_values)
y=y[641:649]
params, covariance = curve_fit(generate_parabola, X, y,p0=[642,1,4400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.999907733415885
# 643.1097641443786

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][980:1050], y_values[980:1050])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[989:997], y_values[989:997])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[989:997]
y=list(y_values)
y=y[989:997]
params, covariance = curve_fit(generate_parabola, X, y,p0=[991,1,9000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9963218850997531
# 991.2690096496625

# %%
plt.scatter(x_values[1036:1043], y_values[1036:1043])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1036:1043]
y=list(y_values)
y=y[1036:1043]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1037,1,9600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999332536645369
# 1038.2670679189202

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1120:1170], y_values[1120:1170])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1126:1135], y_values[1126:1135])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1126:1135]
y=list(y_values)
y=y[1126:1135]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1129,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9986814369733539
# 1129.713845341148

# %%
plt.scatter(x_values[1147:1154], y_values[1147:1154])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1147:1154]
y=list(y_values)
y=y[1147:1154]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1149,1,5400,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9982043416506982
# 1149.1408829343602

# %%
plt.scatter(x_values[1160:1168], y_values[1160:1168])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1160:1168]
y=list(y_values)
y=y[1160:1168]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1162,1,8500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9989421841762991
# 1162.8268437593815

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1210:1270], y_values[1210:1270])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1223:1235], y_values[1223:1235])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1223:1235]
y=list(y_values)
y=y[1223:1235]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1226,1,6500,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9999537908969153
# 1226.909166354858

# %%
plt.scatter(x_values[1245:1252], y_values[1245:1252])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1245:1252]
y=list(y_values)
y=y[1245:1252]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1246,1,8600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9975843999803532
# 1247.1291194362616

# %%
plt.scatter(x_values[1260:1268], y_values[1260:1268])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1260:1268]
y=list(y_values)
y=y[1260:1268]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1261,1,6600,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9976775051121081
# 1261.9433685140189

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][1340:1380], y_values[1340:1380])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[1344:1352], y_values[1344:1352])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1344:1352]
y=list(y_values)
y=y[1344:1352]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1346,1,7000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9973648559553433
# 1346.6406511884331

# %%
plt.scatter(x_values[1359:1369], y_values[1359:1369])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[1359:1369]
y=list(y_values)
y=y[1359:1369]
params, covariance = curve_fit(generate_parabola, X, y,p0=[1361,1,5000,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9994538200866779
# 1361.850135595675

# %%
fig,ax = plt.subplots(ncols=2,figsize=(10,5))
for i in range(2):
    plt.sca(ax[i])
    plt.plot(posiciones[i][140:160], y_values[140:160])
    plt.grid(True)
# Show the plot

# %%
plt.scatter(x_values[148:155], y_values[148:155])
plt.grid(True)
X= list(df["Distance_(pixels)"])
X=X[148:155]
y=list(y_values)
y=y[148:155]
params, covariance = curve_fit(generate_parabola, X, y,p0=[150,1,4300,1])
centro=params[0]
Centros.append(centro)
RESIDUALES(X,y,params)
# Out:
# 0.9998776544894487
# 150.41986609910467

# %% [markdown]
# # Calculo Velocidades

# %%
Lineas_abs_angstrom=[]
for i in range(len(Centros)):
    a=escala(Centros[i],*params_escala)
    Lineas_abs_angstrom.append(a)

# %%
Lineas_abs_angstrom.sort()
print(Lineas_abs_angstrom)
# Out:
# [6280.649538897313, 6291.004256655827, 6297.837625239202, 6301.539422059247, 6302.54583271326, 6309.923690837463, 6311.551390741038, 6314.715908252617, 6315.38774059324, 6315.860940372295, 6318.0756030717275, 6318.774048852972, 6319.285662441979, 6322.208978748928, 6322.7336213565095]

# %%
# Separación de otro elementos del Hierro
indices_to_remove = [6-1, 8-1, 13-1, 14-1,12-1]
Hierros = [Lineas_abs_angstrom[i] for i in range(len(Lineas_abs_angstrom)) if i not in indices_to_remove]
print(Hierros)
# Out:
# [6280.649538897313, 6291.004256655827, 6297.837625239202, 6301.539422059247, 6302.54583271326, 6311.551390741038, 6315.38774059324, 6315.860940372295, 6318.0756030717275, 6322.7336213565095]

# %%
#Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.3063,6315.8110,6318.0171,6322.6851]
#Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.3056,6315.8107,6318.0176,6322.6847]

#La linea 6315.348947813029 resulta en una velocidad atipica respecto al resto de velocidades, se presenta la opción de realizar los calculos estadisticos ignorando este valor atipico con fines comparativos: 

Reales_Air_Hierro=[6280.6178,6290.9658,6297.7927,6301.5008,6302.4932,6311.4999,6315.8110,6318.0171,6322.6851]
Reales_Ritz_Hierro=[6280.6167,6290.9648,6297.7923,6301.4996,6302.4932,6311.4991,6315.8107,6318.0176,6322.6847]
Hierros.pop(6)
# Out:
# 6315.38774059324

# %% [markdown]
# Datos tomados del: NIST Atomic Spectra Database Lines Data

# %%
from scipy.constants import c
def vel_tan(real, doppler):
    #v= ((real/doppler)-1)*c
    v=((doppler-real)/real)*c
    return v
def tiempo(vt):
    vt_km= vt/1000 #metros a kilometros
    ra_sol= 1391016/2
    tiempo_s= (2*np.pi*ra_sol)/np.abs(vt_km)
    tiempo_d= tiempo_s/ (60*60*24)   #segundos a dias
    return tiempo_d

# %%
velocidades_Air=[]
velocidades_Ritz=[]

# %%
#Fe1
for i in range(len(Hierros)):
    vt1=vel_tan(Reales_Air_Hierro[i], Hierros[i])
    vt2=vel_tan(Reales_Ritz_Hierro[i], Hierros[i])
    velocidades_Air.append(vt1)
    velocidades_Ritz.append(vt2)
    print(vt1)
    print(vt2)
    print("--------------------")
# Out:
# 1514.99141367209
# 1567.497940684361
# --------------------
# 1832.6304328011204
# 1880.2851726101094
# --------------------
# 2138.5664038364303
# 2157.607653989513
# --------------------
# 1837.4356272006432
# 1894.5257132545164
# --------------------
# 2503.5950026074265
# 2503.5950026074265
# --------------------
# 2445.7793020008803
# 2483.7791367728187
# --------------------
# 2370.5185230849406
# 2384.7587295662424
# --------------------
# 2775.9943343201207
# 2752.268914969008
# --------------------
# 2300.658107039052
# 2319.6244020739987
# --------------------

# %% [markdown]
# Calculo Estadistico para Lineas de Hierro

# %%
promedio_hierro_air=sum(velocidades_Air)/len(velocidades_Air)
promedio_hierro_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
std_hierro_air=np.std(velocidades_Air)
std_hierro_ritz=np.std(velocidades_Ritz)
print("Promedio Air: "+str(promedio_hierro_air)+" .Desviación Estandar: "+str(std_hierro_air))
print("Promedio Ritz: "+str(promedio_hierro_Ritz)+" .Desviación Estandar: "+str(std_hierro_ritz))
print("Promedio General: "+str((promedio_hierro_Ritz+promedio_hierro_air)/2))
# Out:
# Promedio Air: 2191.1299051736337 .Desviación Estandar: 374.5028632830242
# Promedio Ritz: 2215.9936296142214 .Desviación Estandar: 352.9609949019458
# Promedio General: 2203.5617673939278

# %% [markdown]
# Calculo Estadistico para lineas de otros elementos

# %%
#Sc
Real_Air=6309.88
Doppler=Lineas_abs_angstrom[5]
vt1=vel_tan(Real_Air, Doppler)
velocidades_Air.append(vt1)
print(vt1)
# Out:
# 2075.821339733076

# %%
#Ni
Real_Air=6314.66
Real_Ritz=6314.659
Doppler=Lineas_abs_angstrom[7]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 2654.279482114211
# 2701.7555393867506

# %%
#Mg
Real_Air=6319.236
Real_Ritz=6319.237
Doppler=Lineas_abs_angstrom[12]
vt1=vel_tan(Real_Air, Doppler)
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Air.append(vt1)
velocidades_Ritz.append(vt2)
print(vt1)
print(vt2)
# Out:
# 2356.0483500314126
# 2308.6067341987696

# %%
#Ni
Real_Ritz=6322.166 	
Doppler=Lineas_abs_angstrom[13]
vt2=vel_tan(Real_Ritz, Doppler)
velocidades_Ritz.append(vt2)
print(vt2)
# Out:
# 2038.0206376621613

# %%
len(velocidades_Air)
# Out:
# 12

# %%
promedio_otros_air=sum(velocidades_Air[10:])/len(velocidades_Air[10:])
promedio_otros_Ritz=sum(velocidades_Ritz[10:])/len(velocidades_Ritz[10:])
std_otros_air=np.std(velocidades_Air[10:])
std_otros_ritz=np.std(velocidades_Ritz[10:])
print("Promedio Air: "+str(promedio_otros_air)+" .Desviación Estandar: "+str(std_otros_air))
print("Promedio Ritz: "+str(promedio_otros_Ritz)+" .Desviación Estandar: "+str(std_otros_ritz))
print("Promedio General: "+str((promedio_otros_Ritz+promedio_otros_air)/2))
# Out:
# Promedio Air: 2505.163916072812 .Desviación Estandar: 149.11556604139923
# Promedio Ritz: 2173.3136859304655 .Desviación Estandar: 135.29304826830412
# Promedio General: 2339.2388010016384

# %% [markdown]
# # Calculos Estadisticos Generales

# %%
#Promedio
promedio_Air=sum(velocidades_Air)/len(velocidades_Air)
promedio_Ritz=sum(velocidades_Ritz)/len(velocidades_Ritz)
print(promedio_Air)
print(promedio_Ritz)
# Out:
# 2233.859859870117
# 2249.3604648146397

# %%
promedio_ge=(sum(velocidades_Air)+sum(velocidades_Ritz))/(len(velocidades_Ritz)+len(velocidades_Air))
promedio_ge
# Out:
# 2241.6101623423783

# %%
#Desviación Estandar
std_air=np.std(velocidades_Air)
std_ritz=np.std(velocidades_Ritz)
print(std_air)
print(std_ritz)
# Out:
# 353.00649810624276
# 339.6185645930656

# %%
plt.hist(velocidades_Air,bins=6,label="Air",alpha=0.5)
plt.hist(velocidades_Ritz,bins=6,label="Ritz",alpha=0.5)
plt.legend()

# %% [markdown]
# # Enfoque Espectografo

# %%
Hierros[0]
# Out:
# 6280.649538897313

# %%
Hierros[-1]
# Out:
# 6322.7336213565095

# %%
enfoque=(Hierros[0]+Hierros[-1])/2
enfoque=enfoque/10000
sen_phi=(2*enfoque*1.2)/(2*np.cos((4.5*(np.pi/180))))
phy=np.arcsin(sen_phi)
phy=np.degrees(phy)
phy
# Out:
# 49.33577203153395

# %%
import csv

def export_to_csv(list1, list2, filename):
    if len(list1) != len(list2):
        raise ValueError("Lists must be of equal length")

    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Velocidades_Air', 'Velocidades_Ritz'])  # Writing header row
        for item1, item2 in zip(list1, list2):
            writer.writerow([item1, item2])

# %%
export_to_csv(velocidades_Air, velocidades_Ritz, 'Velocidades_G.csv')
